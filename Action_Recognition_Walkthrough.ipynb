# %% [markdown]
# # Get colab access file (Run this cell for every google account)
# This will download 'cred_this_is_me.txt' which is your credentials file to access your drive from drive api / the code will access your drive folders/files to save and load models trained on colab
#
# Look at the **LICENSE**  and don't use a google account with any critical information (the credentials file will be downloaded locally so keep it safe)
#
# You will need to run this cell for each drive account you have(look at the account you are using from top left of the page)

# %%
# SECUIRTY DISCLAIMER: please look at the LICENCE file given with the code
# make sure your are signed up with the google account you need to use with this code (the code can read/write data to your drive)
# --------------------------------------------------------------------------------------------------------------------------------
# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import files

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
gauth.SaveCredentialsFile('cred_this_is_me.txt') # we need this to start with cred*
files.download('cred_this_is_me.txt') # download and keep it safe you will need it later to identify your account
drive = GoogleDrive(gauth)

# %% [markdown]
# # Installations and system checking
#
# We need at least 100GB of storage where some colab machines are only 40 GB of storage which won't be enough.
#
# **Please clone this notebook, don't copy the cells.**

# %%
# !df ~ --block-size=G
#!du --block-size=M
# Out:
# Filesystem     1G-blocks  Used Available Use% Mounted on
# overlay             359G   74G      267G  22% /

# %%
# %%sh
# pip install tqdm 2> s.txt >> s.txt
# pip3 install http://download.pytorch.org/whl/cu80/torch-0.3.1-cp36-cp36m-linux_x86_64.whl  2> s.txt >> s.txt
# pip3 install torchvision 2> s.txt >> s.txt
# pip install -U -q PyDrive 2> s.txt >> s.txt
# pip install opencv-python 2> s.txt >> s.txt
# #https://www.cyberciti.biz/tips/what-is-devshm-and-its-practical-usage.html
# mount -o remount,size=8G /dev/shm
# pip install imgaug 2> s.txt >> s.txt
#
# # THE REPO .. you are supposed to replace the code below using transfer.sh
# git clone https://github.com/mohammed-elkomy/two-stream-action-recognition.git
# Out:
# Process is interrupted.

# %%
import os 
os.chdir("/content/two-stream-action-recognition")

# %% [markdown]
# # Download & unzip : Processed data as frames (RGB)
# Here I download the processed frames .. They are zipped into one file splitted into three parts..
#
# when unziped it should be 33GB

# %%
# %%sh
# # at /content/two-stream-action-recognition
# wget http://ftp.tugraz.at/pub/feichtenhofer/tsfusion/data/ucf101_jpegs_256.zip.001 &
# wget http://ftp.tugraz.at/pub/feichtenhofer/tsfusion/data/ucf101_jpegs_256.zip.002 &
# wget http://ftp.tugraz.at/pub/feichtenhofer/tsfusion/data/ucf101_jpegs_256.zip.003 &

# %%
# %%sh
# # at /content/two-stream-action-recognition
# cat ucf101_jpegs_256.zip.00* > ucf101_jpegs_256.zip &

# %%
# at /content/two-stream-action-recognition
# !rm ucf101_jpegs_256.zip.00*

# %%
# %%sh
# # at /content/two-stream-action-recognition
# unzip ucf101_jpegs_256.zip >> zip1.out &
#
# # data path has this format
# #v_ApplyEyeMakeup_g01_c01      v_Knitting_g16_c03
# #v_ApplyEyeMakeup_g01_c02      v_Knitting_g16_c04
# #v_ApplyEyeMakeup_g01_c03      v_Knitting_g16_c05
# #v_ApplyEyeMakeup_g01_c04      v_Knitting_g17_c01
#
# # each video folder has this format
# #frame000001.jpg  frame000047.jpg  frame000093.jpg  frame000139.jpg
# #frame000002.jpg  frame000048.jpg  frame000094.jpg  frame000140.jpg
# #frame000003.jpg  frame000049.jpg  frame000095.jpg  frame000141.jpg
# #frame000004.jpg  frame000050.jpg  frame000096.jpg  frame000142.jpg

# %%
# at /content/two-stream-action-recognition
# !rm ucf101_jpegs_256.zip

# %%
# view the data jpegs_256 should be 33G
# !du -sh --human-readable *
# Out:
# 4.0K	average_fusion_demo.py
# 28K	configs
# 36K	evaluation
# 648K	frame_dataloader
# 8.0K	generate_motion_feature_dataset.py
# 8.0K	generate_spatial_feature_dataset.py
# 33G	jpegs_256
# 12K	LICENSE
# 48K	models
# 8.0K	motion_trainer.py
# 4.0K	readme.md
# 16K	recurrent_fusion_trainer.py
# 8.0K	spatial_trainer.py
# 1.6M	UCF_list
# 4.0K	upload.sh
# 64K	utils
# 149M	zip1.out

# %% [markdown]
# # Download & unzip : Processed data as frames (Flow)
# Here I download the processed u/v optical flow frames ..
#
# They are zipped into one file splitted into three parts.. when unziped it should be 31GB

# %%
# %%sh
# # at /content/two-stream-action-recognition
# wget http://ftp.tugraz.at/pub/feichtenhofer/tsfusion/data/ucf101_tvl1_flow.zip.001 &
# wget http://ftp.tugraz.at/pub/feichtenhofer/tsfusion/data/ucf101_tvl1_flow.zip.002 &
# wget http://ftp.tugraz.at/pub/feichtenhofer/tsfusion/data/ucf101_tvl1_flow.zip.003 &
# Out:
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
# %%sh
# # at /content/two-stream-action-recognition
# cat ucf101_tvl1_flow.zip.00* > ucf101_tvl1_flow.zip &

# %%
# at /content/two-stream-action-recognition
# !rm ucf101_tvl1_flow.zip.00*

# %%
# %%sh
# # at /content/two-stream-action-recognition
# unzip ucf101_tvl1_flow.zip >> zip2.out &
#
# # data path has
# # u v
#
# # both u and v has format
# #v_ApplyEyeMakeup_g01_c01      v_Knitting_g16_c03
# #v_ApplyEyeMakeup_g01_c02      v_Knitting_g16_c04
# #v_ApplyEyeMakeup_g01_c03      v_Knitting_g16_c05
# #v_ApplyEyeMakeup_g01_c04      v_Knitting_g17_c01
#
# # each video folder has this format
# #frame000001.jpg  frame000047.jpg  frame000093.jpg  frame000139.jpg
# #frame000002.jpg  frame000048.jpg  frame000094.jpg  frame000140.jpg
# #frame000003.jpg  frame000049.jpg  frame000095.jpg  frame000141.jpg
# #frame000004.jpg  frame000050.jpg  frame000096.jpg  frame000142.jpg

# %%
# at /content/two-stream-action-recognition
# !rm ucf101_tvl1_flow.zip

# %%
# view the data tvl1_flow should be 31G
# !du -sh --human-readable *
# Out:
# 4.0K	average_fusion_demo.py
# 28K	configs
# 36K	evaluation
# 648K	frame_dataloader
# 8.0K	generate_motion_feature_dataset.py
# 8.0K	generate_spatial_feature_dataset.py
# 33G	jpegs_256
# 12K	LICENSE
# 48K	models
# 8.0K	motion_trainer.py
# 4.0K	readme.md
# 16K	recurrent_fusion_trainer.py
# 8.0K	spatial_trainer.py
# 31G	tvl1_flow
# 1.6M	UCF_list
# 4.0K	upload.sh
# 64K	utils
# 149M	zip1.out
# 307M	zip2.out

# %% [markdown]
# # Download sample to your local machine to view the images
#
# Download to your local machine : RGB frames of v_ApplyEyeMakeup_g01_c01
#
# Download to your local machine : u optical flow frames of v_ApplyEyeMakeup_g01_c01
#
# Download to your local machine : v optical flow frames of v_ApplyEyeMakeup_g01_c01

# %%
# !ls /content/two-stream-action-recognition/jpegs_256/v_ApplyEyeMakeup_g01_c01
# !ls /content/two-stream-action-recognition/tvl1_flow/u/v_ApplyEyeMakeup_g01_c01

import os
from google.colab import files
from shutil import copyfile
root = "/content/two-stream-action-recognition/tvl1_flow/v/v_ApplyEyeMakeup_g01_c01"

for index,frame in enumerate(os.listdir(root)):
  copyfile(os.path.join(root,frame), "/tmp/tvl1_flow_v_{}".format(index))
  files.download("/tmp/tvl1_flow_v_{}".format(index))

root = "/content/two-stream-action-recognition/tvl1_flow/u/v_ApplyEyeMakeup_g01_c01"

for index,frame in enumerate(os.listdir(root)):
  copyfile(os.path.join(root,frame), "/tmp/tvl1_flow_u_{}".format(index))
  files.download("/tmp/tvl1_flow_u_{}".format(index))
  
root = "/content/two-stream-action-recognition/jpegs_256/v_ApplyEyeMakeup_g01_c01"

for index,frame in enumerate(os.listdir(root)):
  copyfile(os.path.join(root,frame), "/tmp/jpegs_256_{}".format(index))
  files.download("/tmp/jpegs_256_{}".format(index))
# Out:
# frame000001.jpg  frame000042.jpg  frame000083.jpg  frame000124.jpg
# frame000002.jpg  frame000043.jpg  frame000084.jpg  frame000125.jpg
# frame000003.jpg  frame000044.jpg  frame000085.jpg  frame000126.jpg
# frame000004.jpg  frame000045.jpg  frame000086.jpg  frame000127.jpg
# frame000005.jpg  frame000046.jpg  frame000087.jpg  frame000128.jpg
# frame000006.jpg  frame000047.jpg  frame000088.jpg  frame000129.jpg
# frame000007.jpg  frame000048.jpg  frame000089.jpg  frame000130.jpg
# frame000008.jpg  frame000049.jpg  frame000090.jpg  frame000131.jpg
# frame000009.jpg  frame000050.jpg  frame000091.jpg  frame000132.jpg
# frame000010.jpg  frame000051.jpg  frame000092.jpg  frame000133.jpg
# frame000011.jpg  frame000052.jpg  frame000093.jpg  frame000134.jpg
# frame000012.jpg  frame000053.jpg  frame000094.jpg  frame000135.jpg
# frame000013.jpg  frame000054.jpg  frame000095.jpg  frame000136.jpg
# frame000014.jpg  frame000055.jpg  frame000096.jpg  frame000137.jpg
# frame000015.jpg  frame000056.jpg  frame000097.jpg  frame000138.jpg
# frame000016.jpg  frame000057.jpg  frame000098.jpg  frame000139.jpg
# frame000017.jpg  frame000058.jpg  frame000099.jpg  frame000140.jpg
# frame000018.jpg  frame000059.jpg  frame000100.jpg  frame000141.jpg
# frame000019.jpg  frame000060.jpg  frame000101.jpg  frame000142.jpg
# frame000020.jpg  frame000061.jpg  frame000102.jpg  frame000143.jpg
# frame000021.jpg  frame000062.jpg  frame000103.jpg  frame000144.jpg
# frame000022.jpg  frame000063.jpg  frame000104.jpg  frame000145.jpg
# frame000023.jpg  frame000064.jpg  frame000105.jpg  frame000146.jpg
# frame000024.jpg  frame000065.jpg  frame000106.jpg  frame000147.jpg
# frame000025.jpg  frame000066.jpg  frame000107.jpg  frame000148.jpg
# frame000026.jpg  frame000067.jpg  frame000108.jpg  frame000149.jpg
# frame000027.jpg  frame000068.jpg  frame000109.jpg  frame000150.jpg
# frame000028.jpg  frame000069.jpg  frame000110.jpg  frame000151.jpg
# frame000029.jpg  frame000070.jpg  frame000111.jpg  frame000152.jpg
# frame000030.jpg  frame000071.jpg  frame000112.jpg  frame000153.jpg
# frame000031.jpg  frame000072.jpg  frame000113.jpg  frame000154.jpg
# frame000032.jpg  frame000073.jpg  frame000114.jpg  frame000155.jpg
# frame000033.jpg  frame000074.jpg  frame000115.jpg  frame000156.jpg
# frame000034.jpg  frame000075.jpg  frame000116.jpg  frame000157.jpg
# frame000035.jpg  frame000076.jpg  frame000117.jpg  frame000158.jpg
# frame000036.jpg  frame000077.jpg  frame000118.jpg  frame000159.jpg
# frame000037.jpg  frame000078.jpg  frame000119.jpg  frame000160.jpg
# frame000038.jpg  frame000079.jpg  frame000120.jpg  frame000161.jpg
# frame000039.jpg  frame000080.jpg  frame000121.jpg  frame000162.jpg
# frame000040.jpg  frame000081.jpg  frame000122.jpg  frame000163.jpg
# frame000041.jpg  frame000082.jpg  frame000123.jpg
# frame000001.jpg  frame000042.jpg  frame000083.jpg  frame000124.jpg
# frame000002.jpg  frame000043.jpg  frame000084.jpg  frame000125.jpg
# frame000003.jpg  frame000044.jpg  frame000085.jpg  frame000126.jpg
# frame000004.jpg  frame000045.jpg  frame000086.jpg  frame000127.jpg
# frame000005.jpg  frame000046.jpg  frame000087.jpg  frame000128.jpg
# frame000006.jpg  frame000047.jpg  frame000088.jpg  frame000129.jpg
# frame000007.jpg  frame000048.jpg  frame000089.jpg  frame000130.jpg
# frame000008.jpg  frame000049.jpg  frame000090.jpg  frame000131.jpg
# frame000009.jpg  frame000050.jpg  frame000091.jpg  frame000132.jpg
# frame000010.jpg  frame000051.jpg  frame000092.jpg  frame000133.jpg
# frame000011.jpg  frame000052.jpg  frame000093.jpg  frame000134.jpg
# frame000012.jpg  frame000053.jpg  frame000094.jpg  frame000135.jpg
# frame000013.jpg  frame000054.jpg  frame000095.jpg  frame000136.jpg
# frame000014.jpg  frame000055.jpg  frame000096.jpg  frame000137.jpg
# frame000015.jpg  frame000056.jpg  frame000097.jpg  frame000138.jpg
# frame000016.jpg  frame000057.jpg  frame000098.jpg  frame000139.jpg
# frame000017.jpg  frame000058.jpg  frame000099.jpg  frame000140.jpg
# frame000018.jpg  frame000059.jpg  frame000100.jpg  frame000141.jpg
# frame000019.jpg  frame000060.jpg  frame000101.jpg  frame000142.jpg
# frame000020.jpg  frame000061.jpg  frame000102.jpg  frame000143.jpg
# frame000021.jpg  frame000062.jpg  frame000103.jpg  frame000144.jpg
# frame000022.jpg  frame000063.jpg  frame000104.jpg  frame000145.jpg
# frame000023.jpg  frame000064.jpg  frame000105.jpg  frame000146.jpg
# frame000024.jpg  frame000065.jpg  frame000106.jpg  frame000147.jpg
# frame000025.jpg  frame000066.jpg  frame000107.jpg  frame000148.jpg
# frame000026.jpg  frame000067.jpg  frame000108.jpg  frame000149.jpg
# frame000027.jpg  frame000068.jpg  frame000109.jpg  frame000150.jpg
# frame000028.jpg  frame000069.jpg  frame000110.jpg  frame000151.jpg
# frame000029.jpg  frame000070.jpg  frame000111.jpg  frame000152.jpg
# frame000030.jpg  frame000071.jpg  frame000112.jpg  frame000153.jpg
# frame000031.jpg  frame000072.jpg  frame000113.jpg  frame000154.jpg
# frame000032.jpg  frame000073.jpg  frame000114.jpg  frame000155.jpg
# frame000033.jpg  frame000074.jpg  frame000115.jpg  frame000156.jpg
# frame000034.jpg  frame000075.jpg  frame000116.jpg  frame000157.jpg
# frame000035.jpg  frame000076.jpg  frame000117.jpg  frame000158.jpg
# frame000036.jpg  frame000077.jpg  frame000118.jpg  frame000159.jpg
# frame000037.jpg  frame000078.jpg  frame000119.jpg  frame000160.jpg
# frame000038.jpg  frame000079.jpg  frame000120.jpg  frame000161.jpg
# frame000039.jpg  frame000080.jpg  frame000121.jpg  frame000162.jpg
# frame000040.jpg  frame000081.jpg  frame000122.jpg  frame000163.jpg
# frame000041.jpg  frame000082.jpg  frame000123.jpg

# %% [markdown]
# #Spatial Stream Model
#
# Here we train a spatial stream model.
#
# I also update the code here for everyrun to try different things

# %%
import os 
os.chdir("/content/two-stream-action-recognition")
# !nvidia-smi
# Out:
# Mon Nov 12 14:59:28 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.44                 Driver Version: 396.44                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   32C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# update the code(on colab) if only needed or you overwrite with older version

# this is uploaded with upload.sh script using transfer.sh with cURL
# !wget -O upload.zip https://transfer.sh/oFQtb/upload.zip > /x.txt
# !unzip -o upload.zip > /x.txt
# Out:
# --2018-11-12 18:27:47--  https://transfer.sh/oFQtb/upload.zip
# Resolving transfer.sh (transfer.sh)... 78.94.240.189
# Connecting to transfer.sh (transfer.sh)|78.94.240.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46775 (46K) [application/zip]
# Saving to: ‘upload.zip’
#
# upload.zip          100%[===================>]  45.68K  56.7KB/s    in 0.8s
#
# 2018-11-12 18:27:56 (56.7 KB/s) - ‘upload.zip’ saved [46775/46775]

# %%
# !python spatial_trainer.py
# Out:
# heavy-spa-xception-adam-1e-05-imnet
# Total Available space from my drive 12.732998470775783
# Took 00:00:05 to Download and unzipped file with ID:19ceINlTXXB96LRQvfv9i44T1H8WoZYa-, titled:150-0.84853-0.84721.zip, saved as:150-0.84853-0.84721.zip
# ****************************************************************************************************
# Model restored
# Current Best 0.84853
# 2018-11-12 18:28:29.815790: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-12 18:28:29.816413: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-12 18:28:29.816471: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-12 18:28:30.117906: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-12 18:28:30.117980: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-12 18:28:30.118022: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2018-11-12 18:28:30.118272: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2018-11-12 18:28:30.118357: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10758 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Traceback (most recent call last):
#   File "spatial_trainer.py", line 67, in <module>
#     train_loader, test_loader, test_video_level_label = data_loader(width=int(spatial_model_restored.inputs[0].shape[1]), height=int(spatial_model_restored.inputs[0].shape[2]), batch_size=get_batch_size(spatial_model_restored, spatial=True)).run()
#   File "/content/frame_dataloader/spatial_dataloader.py", line 88, in __init__
#     data_util_ = DataUtil(path=ucf_list_path, split=ucf_split)
#   File "/content/frame_dataloader/UCF_splitting_kernel.py", line 25, in __init__
#     self.init_action_to_label_mapping()
#   File "/content/frame_dataloader/UCF_splitting_kernel.py", line 28, in init_action_to_label_mapping
#     with open(os.path.join(self.path, 'classInd.txt')) as f:
# FileNotFoundError: [Errno 2] No such file or directory: './UCF_list/classInd.txt'

# %% [markdown]
# # Motion Model Running
#
# Here we train a motion stream model.
#
# I also update the code here for every run to try different things

# %%
import os 
os.chdir("/content/two-stream-action-recognition")
# !nvidia-smi
# Out:
# Mon Nov 12 18:28:51 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.44                 Driver Version: 396.44                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P0    69W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# update the code(on colab) if only needed or you overwrite with older version

# this is uploaded with upload.sh script using transfer.sh with cURL
# !wget -O upload.zip https://transfer.sh/oFQtb/upload.zip > /x.txt
# !unzip -o upload.zip > /x.txt
# Out:
# --2018-11-12 18:28:56--  https://transfer.sh/oFQtb/upload.zip
# Resolving transfer.sh (transfer.sh)... 78.94.240.189
# Connecting to transfer.sh (transfer.sh)|78.94.240.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46775 (46K) [application/zip]
# Saving to: ‘upload.zip’
#
# upload.zip          100%[===================>]  45.68K  14.8KB/s    in 3.1s
#
# 2018-11-12 18:29:10 (14.8 KB/s) - ‘upload.zip’ saved [46775/46775]

# %%
# !python motion_trainer.py
# Out:
# hater-heavy-mot-xception-adam-1e-05-imnet
# Total Available space from my drive 12.732998470775783
# Took 00:00:05 to Download and unzipped file with ID:1JRgmVJvxM_CrUxeDmY_vwcwE1B6pPCSS, titled:5-0.14671-0.14671.zip, saved as:5-0.14671-0.14671.zip
# ****************************************************************************************************
# Model restored
# Current Best 0.14671
# 2018-11-12 18:29:44.793677: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-12 18:29:44.794259: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-12 18:29:44.794312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-12 18:29:45.087866: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-12 18:29:45.087924: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-12 18:29:45.087979: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2018-11-12 18:29:45.088383: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2018-11-12 18:29:45.088470: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10758 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# ==> Validation data : 9537 frames
# ==> Validation data : 71877 frames
# Epoch 6/350
# 2018-11-12 18:30:24.495141: W tensorflow/core/common_runtime/bfc_allocator.cc:211] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.15GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2018-11-12 18:30:24.570794: W tensorflow/core/common_runtime/bfc_allocator.cc:211] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.42GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2018-11-12 18:30:24.835094: W tensorflow/core/common_runtime/bfc_allocator.cc:211] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.38GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2018-11-12 18:30:24.860767: W tensorflow/core/common_runtime/bfc_allocator.cc:211] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.44GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 2018-11-12 18:30:24.912609: W tensorflow/core/common_runtime/bfc_allocator.cc:211] Allocator (GPU_0_bfc) ran out of memory trying to allocate 3.15GiB. The caller indicates that this is not a failure, but may mean that there could be performance gains if more memory were available.
# 113/530 [=====>........................] - ETA: 13:21 - loss: 4.1321 - acc_top_1: 0.0924 - acc_top_5: 0.2714Traceback (most recent call last):
#   File "motion_trainer.py", line 80, in <module>
#     initial_epoch=int(zip_file_name.split("-")[0]))  # get epoch number
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py", line 2177, in fit_generator
#     initial_epoch=initial_epoch)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training_generator.py", line 176, in fit_generator
#     x, y, sample_weight=sample_weight, class_weight=class_weight)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py", line 1940, in train_on_batch
#     outputs = self.train_function(ins)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py", line 2986, in __call__
#     run_metadata=self.run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %% [markdown]
# # Generating :visual features from pre trained networks
#
# It was an experiment to try to generate the visual features of every stream and then train a separate network that fuses them..
#
# **Here's the generation part**

# %%
import os 
os.chdir("/content/two-stream-action-recognition")
# !nvidia-smi
# Out:
# Mon Nov 12 18:33:48 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.44                 Driver Version: 396.44                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   43C    P8    30W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# update the code(on colab) if only needed or you overwrite with older version

# this is uploaded with upload.sh script using transfer.sh with cURL
# !wget -O upload.zip https://transfer.sh/oFQtb/upload.zip > /x.txt
# !unzip -o upload.zip > /x.txt
# Out:
# --2018-11-12 18:33:52--  https://transfer.sh/oFQtb/upload.zip
# Resolving transfer.sh (transfer.sh)... 78.94.240.189
# Connecting to transfer.sh (transfer.sh)|78.94.240.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46775 (46K) [application/zip]
# Saving to: ‘upload.zip’
#
# upload.zip          100%[===================>]  45.68K  1.10KB/s    in 42s
#
# 2018-11-12 18:34:48 (1.10 KB/s) - ‘upload.zip’ saved [46775/46775]

# %%
# generate visual features

# !python generate_spatial_feature_dataset.py
# !python generate_motion_feature_dataset.py
# Out:
# Total Available space from my drive 12.732998470775783
# Took 00:00:05 to Download and unzipped file with ID:17O8JdvaSNJFmbvZtQPIBYNLgM9Um-znf, titled:155-0.86043-0.85937.zip, saved as:spatial.zip
# ****************************************************************************************************
# 2018-11-12 18:35:20.515998: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-12 18:35:20.516455: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-12 18:35:20.516497: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-12 18:35:20.799240: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-12 18:35:20.799305: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-12 18:35:20.799349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2018-11-12 18:35:20.799642: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2018-11-12 18:35:20.799705: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10758 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_spatial (InputLayer)   (None, 299, 299, 3)       0
# _________________________________________________________________
# data_norm (BatchNormalizatio (None, 299, 299, 3)       6
# _________________________________________________________________
# xception (Model)             (None, 10, 10, 2048)      20861480
# _________________________________________________________________
# avg_pool (GlobalAveragePooli (None, 2048)              0
# _________________________________________________________________
# predictions (Dense)          (None, 101)               206949
# =================================================================
# Total params: 21,068,435
# Trainable params: 21,013,901
# Non-trainable params: 54,534
# _________________________________________________________________
# ==> Training data : 9537 videos
# ==> Validation data : 3783 frames
#   0% 0/9537 [00:00<?, ?it/s]tcmalloc: large alloc 1484414976 bytes == 0x2a0fe000 @  0x7f8732988001 0x7f8730295b85 0x7f87302f8b43 0x7f87302faa86 0x7f8730392868 0x511b75 0x4f6070 0x4f3338 0x4f4ab3 0x640862 0x64091a 0x6429e0 0x634117 0x4b6e80 0x7f8732583b97 0x5bf75a
#   5% 505/9537 [03:14<56:07,  2.68it/s]Traceback (most recent call last):
#   File "generate_spatial_feature_dataset.py", line 118, in <module>
#     feature_field, _ = spatial_model_with_2_outputs.predict_on_batch(video_frames)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py", line 2044, in predict_on_batch
#     outputs = self.predict_function(ins)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py", line 2986, in __call__
#     run_metadata=self.run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt
# Total Available space from my drive 12.732998470775783
# Took 00:00:05 to Download and unzipped file with ID:1O8OM6Q01az_71HdMQmWM3op1qJhfsQoI, titled:175-0.84192-0.84007.zip, saved as:motion.zip
# ****************************************************************************************************
# 2018-11-12 18:39:22.429864: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-12 18:39:22.430312: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-12 18:39:22.430351: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-12 18:39:22.708834: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-12 18:39:22.708888: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-12 18:39:22.708913: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2018-11-12 18:39:22.709172: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2018-11-12 18:39:22.709240: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10758 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_motion (InputLayer)    (None, 299, 299, 20)      0
# _________________________________________________________________
# data_norm (BatchNormalizatio (None, 299, 299, 20)      40
# _________________________________________________________________
# xception (Model)             (None, 101)               21073325
# =================================================================
# Total params: 21,073,365
# Trainable params: 21,018,797
# Non-trainable params: 54,568
# _________________________________________________________________
# ==> Training data : 9537 videos
# ==> Validation data : 3783 frames
#   0% 0/9537 [00:00<?, ?it/s]tcmalloc: large alloc 1484414976 bytes == 0x33d16000 @  0x7f19fb690001 0x7f19f8f9db85 0x7f19f9000b43 0x7f19f9002a86 0x7f19f909a868 0x511b75 0x4f6070 0x4f3338 0x4f4ab3 0x640862 0x64091a 0x6429e0 0x634117 0x4b6e80 0x7f19fb28bb97 0x5bf75a
#   2% 155/9537 [04:04<4:33:07,  1.75s/it]Traceback (most recent call last):
#   File "generate_motion_feature_dataset.py", line 125, in <module>
#     feature_field, _ = motion_model_with_2_outputs.predict_on_batch(video_frames)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/engine/training.py", line 2044, in predict_on_batch
#     outputs = self.predict_function(ins)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/keras/backend.py", line 2986, in __call__
#     run_metadata=self.run_metadata)
#   File "/usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py", line 1439, in __call__
#     run_metadata_ptr)
# KeyboardInterrupt

# %% [markdown]
# # Training :visual features from pretrained networks
# It was an experiment to try to generate the visual features of every stream and then train a separate network that fuses them..
#
# **Here's the training part**

# %%
import os 
os.chdir("/content/two-stream-action-recognition")
# !nvidia-smi
# Out:
# Mon Nov 12 18:43:51 2018
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 396.44                 Driver Version: 396.44                    |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla K80           Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   40C    P0    74W / 149W |      0MiB / 11441MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# |  GPU       PID   Type   Process name                             Usage      |
# |=============================================================================|
# |  No running processes found                                                 |
# +-----------------------------------------------------------------------------+

# %%
# update the code(on colab) if only needed or you overwrite with older version

# this is uploaded with upload.sh script using transfer.sh with cURL
# !wget -O upload.zip https://transfer.sh/oFQtb/upload.zip > /x.txt
# !unzip -o upload.zip > /x.txt
# Out:
# --2018-11-12 18:43:56--  https://transfer.sh/oFQtb/upload.zip
# Resolving transfer.sh (transfer.sh)... 78.94.240.189
# Connecting to transfer.sh (transfer.sh)|78.94.240.189|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 46775 (46K) [application/zip]
# Saving to: ‘upload.zip’
#
# upload.zip          100%[===================>]  45.68K  23.8KB/s    in 1.9s
#
# 2018-11-12 18:44:07 (23.8 KB/s) - ‘upload.zip’ saved [46775/46775]

# %%
# !python recurrent_fusion_trainer.py
# Out:
# Total Available space from my drive 12.732998470775783
# Took 00:00:01 to Download and unzipped file with ID:1NsJoxoYM4asqpqWYnmdr-UaBTFu10jAZ, titled:1000-0.90246-0.90219.zip, saved as:1000-0.90246-0.90219.zip
# ****************************************************************************************************
# Total Available space from my drive 12.732998470775783
# Took 00:00:09 to Download and unzipped file with ID:1UzOd-PVrfvXW8EApgzoMRshtUx5uwqeH, titled:test_features_spatial.pickle, saved as:test_features_spatial.pickle
# ****************************************************************************************************
# tcmalloc: large alloc 1484455936 bytes == 0x5f3d8000 @  0x7fc07893f1e7 0x5950ec 0x599a96 0x51187c 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277
# Took 00:00:22 to Download and unzipped file with ID:1AxgFp0XRoWwty0DzBhe1_85cz4W4F434, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle
# ****************************************************************************************************
# tcmalloc: large alloc 1484455936 bytes == 0x5f53c000 @  0x7fc07893f1e7 0x5950ec 0x599a96 0x51187c 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277
# Took 00:00:27 to Download and unzipped file with ID:1UXRAbFsZqsKZxdKVfmB3Sjulv4eRJDsv, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.1
# ****************************************************************************************************
# tcmalloc: large alloc 1484455936 bytes == 0x5f65e000 @  0x7fc07893f1e7 0x5950ec 0x599a96 0x51187c 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x510c78 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f6070 0x4f3338 0x510fb0 0x5119bd 0x4f5277 0x4f3338 0x510fb0 0x5119bd 0x4f5277
# Took 00:00:26 to Download and unzipped file with ID:1rQaGd_DRyu8OwNNbP2V2UzMbLRw9bhGm, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.2
# ****************************************************************************************************
# Took 00:00:25 to Download and unzipped file with ID:1XJCLwO3t7MVoyo6LrVbtooiVxcKG-EWB, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.3
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1JAo--WBqsUlbNk2YFbwqJqTnps85YsmM, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.4
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1AKbIIdAiJdoMl2ZWqYYuNs0IghsCs7kV, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.5
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1vUFZoIajxc8gYxcoaL-8T4odaNwHO_3E, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.6
# ****************************************************************************************************
# Took 00:00:28 to Download and unzipped file with ID:1WXf5aBRx6KX8tyfTRBdElZnvsQz8aqwj, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.7
# ****************************************************************************************************
# Took 00:00:28 to Download and unzipped file with ID:1wCGoz4vXj0QoW6GmkohUWzTCnjDvManE, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.8
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1SYaDyBQQ3ypNb-p08d6qmvYeEAUavckm, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.9
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1P7miZ-yv5KA7y0yhUiRF5VjmZ2NbwLZa, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.10
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1ri3a6gPQeOFDEppd3IruZ1whUuuC3UYO, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.11
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:11gAobt8c-0Fl2UmRs4pcENoPqY8a0MU9, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.12
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1hu1nbVt8BwqKfeJ5PHf_g6oHG22icKbZ, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.13
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:16tFR9AsYRebFxlgPT3vK3yqgvh6Y5bd7, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.14
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1USX_Lu_XiGinMMXfKSwGh-2M_eavjKew, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.15
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1yaJtPe9mvyFOH86MquVdAnQYwywss60t, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.16
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1yidKxkP2rl17LnOOImKxTIkzI78bA2sw, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.17
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:187UMYzrQeZKrRBKO-n-NjNGqbJaY7Shk, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.18
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1TwdkXjtD8m0sDmypD9rqnaEndDsm0rza, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.19
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1o1ctxhh57a0N1UEnGj-e6QUQqHm6kC1a, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.20
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1uKQ1HsXhs4TWxDICiU4ORZYS20bymavh, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.21
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1kBkJYUz9MJKSDv5v06q29W3hSotjxTYv, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.22
# ****************************************************************************************************
# Took 00:00:22 to Download and unzipped file with ID:1uerJt3o-vNKlPjK24yeXlOtPtCOUGpYg, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.23
# ****************************************************************************************************
# Took 00:00:22 to Download and unzipped file with ID:1IiO5UjwX4Pg_xn43UQBqXaTCO822RSLS, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.24
# ****************************************************************************************************
# Took 00:00:22 to Download and unzipped file with ID:1eggQiajWUn2wg7imb56cP69XplmU5TgI, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.25
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1LLnj2rgT3cY3JKXzTjntPTIBTxfsV5M5, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.26
# ****************************************************************************************************
# Took 00:00:23 to Download and unzipped file with ID:1ITjjWJ8HtFDJzgXAL5zw5-3wsGkGlMC6, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.27
# ****************************************************************************************************
# Took 00:00:23 to Download and unzipped file with ID:1aAeV2O-3O_6si8jMc-oWJvro8ax11bzv, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.28
# ****************************************************************************************************
# Took 00:00:23 to Download and unzipped file with ID:1gReJ-vdasaFHqHx23V1pCG5vvOXwdZBZ, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.29
# ****************************************************************************************************
# Took 00:00:22 to Download and unzipped file with ID:1dQAUEC0yq6t84ZXjoK4l379fdk4JeSCL, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.30
# ****************************************************************************************************
# Took 00:00:25 to Download and unzipped file with ID:1-QNG9mYLqO5sN9aYGUECNDf_7c_rOpzA, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.31
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1o1eekGXQYs-ZBBjYyk_nlSLht1RlgV1h, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.32
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1FWVtkMr-YtEzdkI6lOiuZAHPiuJ__inb, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.33
# ****************************************************************************************************
# Took 00:00:25 to Download and unzipped file with ID:1UeZvam9hCwo1QErEdSwdoukUioaPPb07, titled:train_features_spatial.pickle, saved as:train_features_spatial.pickle.34
# ****************************************************************************************************
# Total Available space from my drive 12.732998470775783
# Took 00:00:11 to Download and unzipped file with ID:1SnI-3GHKGu9DtdjZAImGSexuWQTd-xtH, titled:test_features_motion.pickle, saved as:test_features_motion.pickle
# ****************************************************************************************************
# Took 00:00:25 to Download and unzipped file with ID:1l6Z-kda3DLmKbYToRiyBTxHiNkKl9n1I, titled:train_features_motion.pickle, saved as:train_features_motion.pickle
# ****************************************************************************************************
# Took 00:00:21 to Download and unzipped file with ID:1GJpUK_c3dmAv-NFm_C6aVU48QKesljq9, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.1
# ****************************************************************************************************
# Took 00:00:31 to Download and unzipped file with ID:1zGTOtkMW94wK8855cpwHu3Xk2kLCHY0w, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.2
# ****************************************************************************************************
# Took 00:00:21 to Download and unzipped file with ID:1W9aeBt2f_k-dh0lEDK0fcSLu_94B1oys, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.3
# ****************************************************************************************************
# Took 00:00:23 to Download and unzipped file with ID:1cBX2EIxhmxGzt9ob0ZetqVJbcFZuf9Lz, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.4
# ****************************************************************************************************
# Took 00:00:32 to Download and unzipped file with ID:1EypbTRfCiwotxc5uybqjlfJTjSWUtUN8, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.5
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:11ujxmXpjrrC6T0e-taakbUidMOaQfr-3, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.6
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:143qYrFy4GNv7vPA0uCtu4a-ju2u8yk7G, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.7
# ****************************************************************************************************
# Took 00:00:33 to Download and unzipped file with ID:1Qh7K62ZafLb07LXj4AENCmssZ-G-xeGX, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.8
# ****************************************************************************************************
# Took 00:00:23 to Download and unzipped file with ID:16M9WBWVg9NbFb0ClriVyG1vJvC1DYoXk, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.9
# ****************************************************************************************************
# Took 00:00:32 to Download and unzipped file with ID:1dmW7dNoC7QsoIDflGv4GKT5hH5geb-PL, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.10
# ****************************************************************************************************
# Took 00:00:42 to Download and unzipped file with ID:1F8Y0TwTyZUBrMc1D-d7Zt-h8rhbjh34y, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.11
# ****************************************************************************************************
# Took 00:00:31 to Download and unzipped file with ID:13sym1okYGskCMhpii9fdQOuC1a8wnVJO, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.12
# ****************************************************************************************************
# Took 00:00:22 to Download and unzipped file with ID:1ag_udcU4B-OJFD-sFEfDDDG9wdRvdT5f, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.13
# ****************************************************************************************************
# Took 00:00:31 to Download and unzipped file with ID:13iMtO_8jL_PaWeVJU5vwxxxrtzoq4OdL, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.14
# ****************************************************************************************************
# Took 00:00:25 to Download and unzipped file with ID:1MEbhzn3ou30Zzw6VrSiD_l1Mv-M8DpdV, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.15
# ****************************************************************************************************
# Took 00:00:24 to Download and unzipped file with ID:12D3H_EJbZjFx6ABWkvN6rAADYUdTm3QN, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.16
# ****************************************************************************************************
# Took 00:00:23 to Download and unzipped file with ID:1vccHfj5vngKDnRqbUWpGQQwqZCdh5o-a, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.17
# ****************************************************************************************************
# Took 00:00:26 to Download and unzipped file with ID:1T0XpT7t-iyOCac-mzSdoWG_rxg9DoO-R, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.18
# ****************************************************************************************************
# Took 00:00:24 to Download and unzipped file with ID:1JBbw4rakrh6d2PJIxBUnY3K86zDhhicY, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.19
# ****************************************************************************************************
# Took 00:00:24 to Download and unzipped file with ID:1bqIfBHHuxgQf-NrbY1AROzJVmNA25Jpc, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.20
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1zaSJnUifzC5jKPDCyBdYO9d2xa_RpFlq, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.21
# ****************************************************************************************************
# Took 00:00:25 to Download and unzipped file with ID:11JKLWZ2jpbOoU5qsZRcqildkow3M4r6y, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.22
# ****************************************************************************************************
# Took 00:00:23 to Download and unzipped file with ID:1ua-CcSoCDFpuu96SizJxT8ZmpMzraIS3, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.23
# ****************************************************************************************************
# Took 00:00:31 to Download and unzipped file with ID:1bq0Wdtr87syS12HF7qY01Y9SBfOs3n1W, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.24
# ****************************************************************************************************
# Took 00:00:28 to Download and unzipped file with ID:1DYSZJn0adFTBPbtEQ5ziRyBuka4nw9_p, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.25
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1JGS9T1d3-586CEf6D43ro3QMMlYObhCr, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.26
# ****************************************************************************************************
# Took 00:00:30 to Download and unzipped file with ID:1KqMcMgnCRrBrg2BZY95ASEbzKoesWKms, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.27
# ****************************************************************************************************
# Took 00:00:28 to Download and unzipped file with ID:1UaaLjkamGr7uJ-C0HNf5q2Iz2xK6lhlm, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.28
# ****************************************************************************************************
# Took 00:00:24 to Download and unzipped file with ID:1JlINpr5EQ-3VOpx2CpFDrqrtw7lKdK1I, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.29
# ****************************************************************************************************
# Took 00:00:27 to Download and unzipped file with ID:1QxtrwnI-lpjKMikngIfRepDo_GQT1Lr7, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.30
# ****************************************************************************************************
# Took 00:00:24 to Download and unzipped file with ID:1DcShWrG-f5EyqvS6nKDfoQmguaYhrV49, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.31
# ****************************************************************************************************
# Took 00:00:37 to Download and unzipped file with ID:11vfeH2C_8qocKC5M-WqpHfmXt_5x13p1, titled:train_features_motion.pickle, saved as:train_features_motion.pickle.32
# ****************************************************************************************************
# Tensor("mul:0", shape=(?, 19, 128), dtype=float32)
# Tensor("Sum:0", shape=(?, 128), dtype=float32)
# 2018-11-12 19:16:08.652359: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:964] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2018-11-12 19:16:08.653176: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1432] Found device 0 with properties:
# name: Tesla K80 major: 3 minor: 7 memoryClockRate(GHz): 0.8235
# pciBusID: 0000:00:04.0
# totalMemory: 11.17GiB freeMemory: 11.10GiB
# 2018-11-12 19:16:08.653239: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1511] Adding visible gpu devices: 0
# 2018-11-12 19:16:08.956226: I tensorflow/core/common_runtime/gpu/gpu_device.cc:982] Device interconnect StreamExecutor with strength 1 edge matrix:
# 2018-11-12 19:16:08.956271: I tensorflow/core/common_runtime/gpu/gpu_device.cc:988]      0
# 2018-11-12 19:16:08.956298: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1001] 0:   N
# 2018-11-12 19:16:08.956572: W tensorflow/core/common_runtime/gpu/gpu_bfc_allocator.cc:42] Overriding allow_growth setting because the TF_FORCE_GPU_ALLOW_GROWTH environment variable is set. Original config value was 0.
# 2018-11-12 19:16:08.956652: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1115] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 10758 MB memory) -> physical GPU (device: 0, name: Tesla K80, pci bus id: 0000:00:04.0, compute capability: 3.7)
# Model restored
# Current Best 0.90246

# %% [markdown]
# # Downloading Original data as videos from UCF authors
# This's the original data of UCF101 (not processed frames.. they are the actual videos)
# I like the processed frames so I don't need to run optical flow algorithm which is resource-intensive
#
# You can train networks the works on videos themselves and share the results !
# (RNNS / 3D convs ...)

# %%
# !wget "http://crcv.ucf.edu/data/UCF101/UCF101.rar"
# !apt install unrar
# !unrar x UCF101.rar >> out.txt
# !rm out.txt

# %%
# !ls UCF-101
#each folder is just avi files
# !ls UCF-101/Knitting/v_Knitting_g17_c04.avi

# !echo "==="
# !ls UCF-101/HandstandPushups

# %%
from google.colab import files
#files.download('UCF-101/Knitting/v_Knitting_g17_c04.avi')

import cv2
vidcap = cv2.VideoCapture('UCF-101/Knitting/v_Knitting_g17_c04.avi')
success,image = vidcap.read()
count = 0
while success:
  cv2.imwrite("frame%d.jpg" % count, image)     # save frame as JPEG file      
  success,image = vidcap.read()
  #print('Read a new frame: ', success)
  count += 1
  
print(count) # 182 also in dictionary
# Out:
# 182

# %% [markdown]
# # Flownet(Failed experiment)(Left as future work)

# %%
# !git clone https://github.com/sampepose/flownet2-tf.git
# !pip install pypng
# Out:
# Cloning into 'flownet2-tf'...
# remote: Counting objects: 648, done.
# remote: Total 648 (delta 0), reused 0 (delta 0), pack-reused 648
# Receiving objects: 100% (648/648), 16.76 MiB | 14.63 MiB/s, done.
# Resolving deltas: 100% (397/397), done.
# Collecting pypng
#   Downloading https://files.pythonhosted.org/packages/2f/b1/c8dfcf50feb12a30be7d95c5f45d638704682487d8e50419ef41463febcd/pypng-0.0.18.tar.gz (377kB)
#     100% |████████████████████████████████| 378kB 19.6MB/s
# Building wheels for collected packages: pypng
# done
#   Stored in directory: /root/.cache/pip/wheels/ed/30/6c/21dd4d267f47ea09fb57881b30fe16f7231b71bd26dea38afc
# Successfully built pypng
# Installing collected packages: pypng
# Successfully installed pypng-0.0.18

# %%
# !ls  flownet2-tf/checkpoints/
# Out:
# download.sh  README.md

# %%
import os
os.chdir("flownet2-tf/checkpoints/")

# %%
# !sh download.sh
# Out:
# --2018-09-01 01:06:12--  https://s3.us-east-2.amazonaws.com/flownetdata/weights.tar.gz
# Resolving s3.us-east-2.amazonaws.com (s3.us-east-2.amazonaws.com)... 52.219.100.50
# Connecting to s3.us-east-2.amazonaws.com (s3.us-east-2.amazonaws.com)|52.219.100.50|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4447692275 (4.1G) [application/x-tar]
# Saving to: ‘weights.tar.gz’
#
# weights.tar.gz      100%[===================>]   4.14G  32.4MB/s    in 2m 20s
#
# 2018-09-01 01:08:33 (30.2 MB/s) - ‘weights.tar.gz’ saved [4447692275/4447692275]

# %%
import os
os.chdir("..")

# %%
# !wget -O upload.zip https://transfer.sh/oHyYz/upload.zip > /x.txt
# !unzip -o upload.zip > /x.txt
# Out:
# --2018-09-01 01:09:52--  https://transfer.sh/oHyYz/upload.zip
# Resolving transfer.sh (transfer.sh)... 185.216.24.82
# Connecting to transfer.sh (transfer.sh)|185.216.24.82|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 32382 (32K) [application/zip]
# Saving to: ‘upload.zip’
#
# upload.zip          100%[===================>]  31.62K  --.-KB/s    in 0.03s
#
# 2018-09-01 01:09:53 (980 KB/s) - ‘upload.zip’ saved [32382/32382]

# %%
# !apt update -qq;
# !wget https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb;
# !dpkg -i cuda-repo-ubuntu1604–8–0-local-ga2_8.0.61–1_amd64-deb 2> /dev/null;
# !apt-key add /var/cuda-repo-8–0-local-ga2/7fa2af80.pub;
# !apt-get update -qq;
# !apt-get install cuda gcc-5 g++-5 -y -qq;
# !ln -s /usr/bin/gcc-5 /usr/local/cuda/bin/gcc;
# !ln -s /usr/bin/g++-5 /usr/local/cuda/bin/g++;
# !apt install cuda-8.0;
# Out:
# All packages are up to date.
# --2018-09-01 01:38:56--  https://developer.nvidia.com/compute/cuda/8.0/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb
# Resolving developer.nvidia.com (developer.nvidia.com)... 192.229.182.215
# Connecting to developer.nvidia.com (developer.nvidia.com)|192.229.182.215|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?zv9nMf3EgR7eIyp0vp5jQI0sXkAar71rdw8og_GwxGvB3_dm8UnwX1BU8svQZADArD9kksWZpCQQDirnQoB0aGtjp1s1iW2-gB2VmSdnfJxGXEYyJzW8KR4817hernMlwAnMrWrxDktZTcNkc4zSAADeIiTVnRlLmwnJpKbURviySHLJIUMWHeP4FBmz_nUjYOHCbWWQhKtmRExImKi0vfQykw [following]
# --2018-09-01 01:38:57--  https://developer.download.nvidia.com/compute/cuda/8.0/secure/Prod2/local_installers/cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64.deb?zv9nMf3EgR7eIyp0vp5jQI0sXkAar71rdw8og_GwxGvB3_dm8UnwX1BU8svQZADArD9kksWZpCQQDirnQoB0aGtjp1s1iW2-gB2VmSdnfJxGXEYyJzW8KR4817hernMlwAnMrWrxDktZTcNkc4zSAADeIiTVnRlLmwnJpKbURviySHLJIUMWHeP4FBmz_nUjYOHCbWWQhKtmRExImKi0vfQykw
# Resolving developer.download.nvidia.com (developer.download.nvidia.com)... 192.229.221.58, 2606:2800:233:ef6:15dd:1ece:1d50:1e1
# Connecting to developer.download.nvidia.com (developer.download.nvidia.com)|192.229.221.58|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1913589814 (1.8G) [application/x-deb]
# Saving to: ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’
#
# cuda-repo-ubuntu160 100%[===================>]   1.78G   123MB/s    in 15s
#
# 2018-09-01 01:39:11 (125 MB/s) - ‘cuda-repo-ubuntu1604-8-0-local-ga2_8.0.61-1_amd64-deb’ saved [1913589814/1913589814]
#
# gpg: can't open '/var/cuda-repo-8–0-local-ga2/7fa2af80.pub': No such file or directory
# E: Unable to locate package cuda
# ln: failed to create symbolic link '/usr/local/cuda/bin/gcc': No such file or directory
# ln: failed to create symbolic link '/usr/local/cuda/bin/g++': No such file or directory
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'libcuda-8.0-1' for regex 'cuda-8.0'
# Note, selecting 'libcuda1-384' instead of 'libcuda-8.0-1'
# The following additional packages will be installed:
#   accountsservice acpid activity-log-manager adwaita-icon-theme apg aspell
#   aspell-en at-spi2-core avahi-daemon avahi-utils bbswitch-dkms bind9-host
#   bluez bluez-obexd bsdmainutils cheese-common cracklib-runtime crda
#   cups-pk-helper dbus dbus-user-session dbus-x11 dconf-cli
#   dconf-gsettings-backend dconf-service desktop-file-utils dictionaries-common
#   distro-info-data dkms dmsetup dns-root-data dnsmasq-base dosfstools eject
#   emacsen-common enchant evolution-data-server evolution-data-server-common
#   fakeroot file fontconfig fuse gcr gdisk geoclue geoclue-ubuntu-geoip
#   geoip-database gettext-base gir1.2-atk-1.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0 gir1.2-gtk-3.0 gir1.2-ibus-1.0
#   gir1.2-notify-0.7 gir1.2-packagekitglib-1.0 gir1.2-pango-1.0
#   gir1.2-polkit-1.0 gir1.2-secret-1 gkbd-capplet glib-networking
#   glib-networking-common glib-networking-services gnome-bluetooth
#   gnome-control-center-faces gnome-desktop3-data gnome-keyring gnome-menus
#   gnome-power-manager gnome-screensaver gnome-session-bin
#   gnome-settings-daemon-schemas groff-base gsettings-desktop-schemas
#   gsettings-ubuntu-schemas gstreamer1.0-clutter-3.0 gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache gvfs
#   gvfs-backends gvfs-common gvfs-daemons gvfs-libs hicolor-icon-theme
#   humanity-icon-theme hunspell-en-us ibus ibus-gtk ibus-gtk3 im-config
#   indicator-applet indicator-application indicator-bluetooth indicator-common
#   indicator-datetime indicator-keyboard indicator-messages indicator-power
#   indicator-session indicator-sound ippusbxd iproute2 iptables iputils-arping
#   isc-dhcp-client isc-dhcp-common iso-codes iw keyboard-configuration kmod
#   lib32gcc1 libaa1 libaccounts-glib0 libaccountsservice0 libapparmor1
#   libappindicator3-1 libappstream4 libarchive13 libasound2 libasound2-data
#   libasound2-plugins libaspell15 libasyncns0 libatasmart4 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatm1 libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavahi-core7 libavahi-glib1
#   libavc1394-0 libbind9-140 libbluetooth3 libboost-filesystem1.62.0
#   libboost-system1.62.0 libboost-thread1.62.0 libc6-i386 libcaca0
#   libcairo-gobject2 libcairo2 libcamel-1.2-60 libcanberra-gtk3-0
#   libcanberra-gtk3-module libcanberra-pulse libcanberra0 libcap2 libcap2-bin
#   libcapnp-0.5.3 libcdio-cdda1 libcdio-paranoia1 libcdio13 libcdparanoia0
#   libcheese-gtk25 libcheese8 libclutter-1.0-0 libclutter-1.0-common
#   libclutter-gst-3.0-0 libclutter-gtk-1.0-0 libcogl-common libcogl-pango20
#   libcogl-path20 libcogl20 libcolord2 libcrack2 libcroco3 libcryptsetup4
#   libcups2 libdaemon0 libdatrie1 libdbus-1-3 libdbus-glib-1-2
#   libdbusmenu-glib4 libdbusmenu-gtk3-4 libdconf1 libdee-1.0-4
#   libdevmapper1.02.1 libdns-export162 libdns162 libdrm-amdgpu1 libdrm-common
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libdv4
#   libebackend-1.2-10 libebook-1.2-19 libebook-contacts-1.2-2 libecal-1.2-19
#   libedata-book-1.2-25 libedata-cal-1.2-28 libedataserver-1.2-22 libegl1-mesa
#   libelf1 libenchant1c2a libepoxy0 libevdev2 libexif12 libfakeroot
#   libfcitx-config4 libfcitx-gclient0 libfcitx-utils0 libflac8 libfontenc1
#   libfribidi0 libfuse2 libgail-common libgail18 libgbm1 libgck-1-0
#   libgcr-3-common libgcr-base-3-1 libgcr-ui-3-1 libgd3 libgdata-common
#   libgdata22 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common
#   libgee-0.8-2 libgeoclue0 libgeocode-glib0 libgeoip1 libgeonames-common
#   libgeonames0 libgirepository-1.0-1 libgl1-mesa-dri libgl1-mesa-glx
#   libglapi-mesa libgles2-mesa libglib2.0-bin libglib2.0-data
#   libgnome-bluetooth13 libgnome-desktop-3-12 libgnome-menu-3-0
#   libgnomekbd-common libgnomekbd8 libgoa-1.0-0b libgoa-1.0-common libgphoto2-6
#   libgphoto2-l10n libgphoto2-port12 libgpm2 libgraphite2-3
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgtop-2.0-11 libgtop2-common libgudev-1.0-0
#   libgweather-3-6 libgweather-common libharfbuzz-icu0 libharfbuzz0b
#   libhunspell-1.6-0 libhyphen0 libibus-1.0-5 libical2 libido3-0.1-0
#   libiec61883-0 libimobiledevice6 libindicator3-7 libinput-bin libinput10
#   libip4tc0 libip6tc0 libiptc0 libisc-export160 libisc160 libisccc140
#   libisccfg140 libjack-jackd2-0 libjansson4 libjavascriptcoregtk-4.0-18
#   libjbig0 libjson-c3 libjson-glib-1.0-0 libjson-glib-1.0-common libkmod2
#   liblcms2-2 libldb1 liblightdm-gobject-1-0 libllvm5.0 liblocale-gettext-perl
#   libltdl7 liblwres141 liblzo2-2 libmagic-mgc libmagic1 libmbim-glib4
#   libmbim-proxy libmessaging-menu0 libmirclient9 libmircommon7 libmircore1
#   libmirprotobuf3 libmm-glib0 libmnl0 libmtdev1 libmtp-common libmtp-runtime
#   libmtp9 libndp0 libnetfilter-conntrack3 libnewt0.52 libnfnetlink0
#   libnl-3-200 libnl-genl-3-200 libnm-glib4 libnm-gtk0 libnm-util2 libnm0
#   libnma0 libnotify4 libnspr4 libnss-mdns libnss3 libntfs-3g872 liboauth0
#   libogg0 libopus0 liborc-0.4-0 libp11-kit-gnome-keyring
#   libpackagekit-glib2-18 libpam-cap libpam-gnome-keyring libpam-systemd
#   libpanel-applet3 libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0
#   libpangoxft-1.0-0 libparted2 libpcap0.8 libpci3 libpciaccess0 libpcsclite1
#   libphonenumber7 libpipeline1 libpixman-1-0 libplist3 libplymouth4
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0
#   libprotobuf-lite10 libprotobuf10 libproxy1v5 libpulse-mainloop-glib0
#   libpulse0 libpulsedsp libpwquality-common libpwquality1 libqmi-glib5
#   libqmi-proxy libraw1394-11 librest-0.7-0 librsvg2-2 librsvg2-common
#   libsamplerate0 libseccomp2 libsecret-1-0 libsecret-common libsensors4
#   libshout3 libslang2 libsmbclient libsndfile1 libsoup-gnome2.4-1 libsoup2.4-1
#   libspeex1 libspeexdsp1 libstemmer0d libtag1v5 libtag1v5-vanilla libtalloc2
#   libtdb1 libtevent0 libtext-iconv-perl libthai-data libthai0 libtheora0
#   libtiff5 libtimezonemap-data libtimezonemap1 libtxc-dxtn-s2tc libudisks2-0
#   libunity-control-center1 libunity-settings-daemon1 libupower-glib3
#   liburl-dispatcher1 libusb-1.0-0 libusbmuxd4 libv4l-0 libv4lconvert0
#   libvdpau1 libvisual-0.4-0 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx4
#   libwacom-bin libwacom-common libwacom2 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1-mesa libwayland-server0 libwbclient0
#   libwebkit2gtk-4.0-37 libwebp6 libwebpdemux2 libwebrtc-audio-processing1
#   libwhoopsie-preferences0 libwhoopsie0 libwrap0 libx11-xcb1 libxapian30
#   libxatracker2 libxaw7 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-render0 libxcb-shape0 libxcb-shm0 libxcb-sync1
#   libxcb-util1 libxcb-xfixes0 libxcomposite1 libxcursor1 libxdamage1
#   libxfixes3 libxfont1 libxfont2 libxi6 libxinerama1 libxkbcommon0 libxkbfile1
#   libxklavier16 libxmu6 libxmuu1 libxnvctrl0 libxpm4 libxrandr2 libxshmfence1
#   libxslt1.1 libxt6 libxtables12 libxtst6 libxv1 libxvmc1 libxxf86dga1
#   libxxf86vm1 libyaml-0-2 libyelp0 libzeitgeist-2.0-0 lightdm
#   linux-headers-4.13.0-46 linux-headers-4.13.0-46-generic
#   linux-headers-generic lsb-release man-db mesa-vdpau-drivers
#   mobile-broadband-provider-info modemmanager mousetweaks nautilus-data
#   network-manager network-manager-gnome network-manager-pptp
#   notification-daemon ntfs-3g nvidia-384 nvidia-opencl-icd-384 nvidia-prime
#   nvidia-settings ocl-icd-libopencl1 p11-kit p11-kit-modules packagekit
#   packagekit-tools parted pciutils pinentry-gnome3 plymouth
#   plymouth-theme-ubuntu-text policykit-1 policykit-1-gnome ppp pptp-linux
#   psmisc pulseaudio pulseaudio-utils python-apt-common python-talloc
#   python3-apt python3-cairo python3-certifi python3-chardet python3-cups
#   python3-cupshelpers python3-dbus python3-gi python3-idna
#   python3-pkg-resources python3-requests python3-six python3-urllib3
#   python3-xdg python3-xkit rtkit samba-libs screen-resolution-extra
#   shared-mime-info sound-theme-freedesktop sudo system-config-printer
#   system-config-printer-common system-config-printer-udev systemd systemd-sysv
#   tcpd ubuntu-mono ubuntu-system-service ubuntu-touch-sounds udev udisks2
#   unity-control-center unity-greeter unity-settings-daemon upower
#   usb-modeswitch usb-modeswitch-data usbmuxd vdpau-driver-all wamerican
#   whoopsie-preferences wireless-regdb wpasupplicant x11-utils x11-xkb-utils
#   xauth xfonts-base xfonts-encodings xfonts-utils xkb-data xserver-common
#   xserver-xorg xserver-xorg-core xserver-xorg-input-all
#   xserver-xorg-input-libinput xserver-xorg-input-wacom xserver-xorg-legacy
#   xserver-xorg-video-all xserver-xorg-video-amdgpu xserver-xorg-video-ati
#   xserver-xorg-video-fbdev xserver-xorg-video-intel xserver-xorg-video-nouveau
#   xserver-xorg-video-qxl xserver-xorg-video-radeon xserver-xorg-video-vesa
#   xserver-xorg-video-vmware yelp yelp-xsl zeitgeist-core zenity zenity-common
# Suggested packages:
#   gnome-control-center aspell-doc spellutils avahi-autoipd bumblebee whois
#   vacation python3-apport menu cdtool setcd evolution groff samba-common
#   hunspell openoffice.org-hunspell | openoffice.org-core ibus-clutter ibus-doc
#   ibus-qt4 libqt5gui5 apport unity-greeter-session-broadcast iproute2-doc
#   resolvconf isc-dhcp-client-ddns isoquery lrzip alsa-utils libcanberra-gtk0
#   colord cups-common libdv-bin oss-compat libenchant-voikko fcitx libgd-tools
#   geoip-bin gphoto2 gpm libvisual-0.4-plugins gstreamer1.0-tools
#   libusbmuxd-tools jackd2 liblcms2-utils avahi-autoipd | zeroconf opus-tools
#   libparted-dev libparted-i18n pcscd libraw1394-doc librsvg2-bin lm-sensors
#   speex url-dispatcher libwebkit2gtk-4.0-37-gtk2 xapian-tools bindfs lsb less
#   www-browser nautilus network-manager-openconnect-gnome
#   network-manager-openvpn-gnome network-manager-vpnc-gnome
#   network-manager-pptp-gnome appstream parted-doc pinentry-doc desktop-base
#   plymouth-themes pavumeter pavucontrol paman paprefs ubuntu-sounds
#   python3-apt-dbg python-apt-doc python-dbus-doc python3-dbus-dbg
#   python3-setuptools python3-cryptography python3-openssl python3-socks
#   gnome-software python3-smbc systemd-container btrfs-progs | btrfs-tools
#   cryptsetup-bin exfat-utils mdadm reiserfsprogs xfsprogs gnome-user-guide
#   | ubuntu-docs libcanberra-gtk-module x11-xserver-utils
#   lightdm-remote-session-freerdp lightdm-remote-session-uccsconfigure
#   remote-login-service metacity | x-window-manager comgt wvdial
#   libvdpau-va-gl1 nvidia-vdpau-driver nvidia-legacy-340xx-vdpau-driver wpagui
#   libengine-pkcs11-openssl mesa-utils xfonts-100dpi | xfonts-75dpi
#   xfonts-scalable xinput firmware-amd-graphics xserver-xorg-video-r128
#   xserver-xorg-video-mach64 firmware-misc-nonfree zeitgeist-datahub
# Recommended packages:
#   systemd-services
# The following NEW packages will be installed:
#   accountsservice acpid activity-log-manager adwaita-icon-theme apg aspell
#   aspell-en at-spi2-core avahi-daemon avahi-utils bbswitch-dkms bind9-host
#   bluez bluez-obexd bsdmainutils cheese-common cracklib-runtime crda
#   cups-pk-helper dbus dbus-user-session dbus-x11 dconf-cli
#   dconf-gsettings-backend dconf-service desktop-file-utils dictionaries-common
#   distro-info-data dkms dmsetup dns-root-data dnsmasq-base dosfstools eject
#   emacsen-common enchant evolution-data-server evolution-data-server-common
#   fakeroot file fontconfig fuse gcr gdisk geoclue geoclue-ubuntu-geoip
#   geoip-database gettext-base gir1.2-atk-1.0 gir1.2-freedesktop
#   gir1.2-gdkpixbuf-2.0 gir1.2-glib-2.0 gir1.2-gtk-3.0 gir1.2-ibus-1.0
#   gir1.2-notify-0.7 gir1.2-packagekitglib-1.0 gir1.2-pango-1.0
#   gir1.2-polkit-1.0 gir1.2-secret-1 gkbd-capplet glib-networking
#   glib-networking-common glib-networking-services gnome-bluetooth
#   gnome-control-center-faces gnome-desktop3-data gnome-keyring gnome-menus
#   gnome-power-manager gnome-screensaver gnome-session-bin
#   gnome-settings-daemon-schemas groff-base gsettings-desktop-schemas
#   gsettings-ubuntu-schemas gstreamer1.0-clutter-3.0 gstreamer1.0-plugins-base
#   gstreamer1.0-plugins-good gstreamer1.0-x gtk-update-icon-cache gvfs
#   gvfs-backends gvfs-common gvfs-daemons gvfs-libs hicolor-icon-theme
#   humanity-icon-theme hunspell-en-us ibus ibus-gtk ibus-gtk3 im-config
#   indicator-applet indicator-application indicator-bluetooth indicator-common
#   indicator-datetime indicator-keyboard indicator-messages indicator-power
#   indicator-session indicator-sound ippusbxd iproute2 iptables iputils-arping
#   isc-dhcp-client isc-dhcp-common iso-codes iw keyboard-configuration kmod
#   lib32gcc1 libaa1 libaccounts-glib0 libaccountsservice0 libapparmor1
#   libappindicator3-1 libappstream4 libarchive13 libasound2 libasound2-data
#   libasound2-plugins libaspell15 libasyncns0 libatasmart4 libatk-bridge2.0-0
#   libatk1.0-0 libatk1.0-data libatm1 libatspi2.0-0 libavahi-client3
#   libavahi-common-data libavahi-common3 libavahi-core7 libavahi-glib1
#   libavc1394-0 libbind9-140 libbluetooth3 libboost-filesystem1.62.0
#   libboost-system1.62.0 libboost-thread1.62.0 libc6-i386 libcaca0
#   libcairo-gobject2 libcairo2 libcamel-1.2-60 libcanberra-gtk3-0
#   libcanberra-gtk3-module libcanberra-pulse libcanberra0 libcap2 libcap2-bin
#   libcapnp-0.5.3 libcdio-cdda1 libcdio-paranoia1 libcdio13 libcdparanoia0
#   libcheese-gtk25 libcheese8 libclutter-1.0-0 libclutter-1.0-common
#   libclutter-gst-3.0-0 libclutter-gtk-1.0-0 libcogl-common libcogl-pango20
#   libcogl-path20 libcogl20 libcolord2 libcrack2 libcroco3 libcryptsetup4
#   libcuda1-384 libcups2 libdaemon0 libdatrie1 libdbus-1-3 libdbus-glib-1-2
#   libdbusmenu-glib4 libdbusmenu-gtk3-4 libdconf1 libdee-1.0-4
#   libdevmapper1.02.1 libdns-export162 libdns162 libdrm-amdgpu1 libdrm-common
#   libdrm-intel1 libdrm-nouveau2 libdrm-radeon1 libdrm2 libdv4
#   libebackend-1.2-10 libebook-1.2-19 libebook-contacts-1.2-2 libecal-1.2-19
#   libedata-book-1.2-25 libedata-cal-1.2-28 libedataserver-1.2-22 libegl1-mesa
#   libelf1 libenchant1c2a libepoxy0 libevdev2 libexif12 libfakeroot
#   libfcitx-config4 libfcitx-gclient0 libfcitx-utils0 libflac8 libfontenc1
#   libfribidi0 libfuse2 libgail-common libgail18 libgbm1 libgck-1-0
#   libgcr-3-common libgcr-base-3-1 libgcr-ui-3-1 libgd3 libgdata-common
#   libgdata22 libgdk-pixbuf2.0-0 libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-common
#   libgee-0.8-2 libgeoclue0 libgeocode-glib0 libgeoip1 libgeonames-common
#   libgeonames0 libgirepository-1.0-1 libgl1-mesa-dri libgl1-mesa-glx
#   libglapi-mesa libgles2-mesa libglib2.0-bin libglib2.0-data
#   libgnome-bluetooth13 libgnome-desktop-3-12 libgnome-menu-3-0
#   libgnomekbd-common libgnomekbd8 libgoa-1.0-0b libgoa-1.0-common libgphoto2-6
#   libgphoto2-l10n libgphoto2-port12 libgpm2 libgraphite2-3
#   libgstreamer-plugins-base1.0-0 libgstreamer-plugins-good1.0-0
#   libgstreamer1.0-0 libgtk-3-0 libgtk-3-bin libgtk-3-common libgtk2.0-0
#   libgtk2.0-bin libgtk2.0-common libgtop-2.0-11 libgtop2-common libgudev-1.0-0
#   libgweather-3-6 libgweather-common libharfbuzz-icu0 libharfbuzz0b
#   libhunspell-1.6-0 libhyphen0 libibus-1.0-5 libical2 libido3-0.1-0
#   libiec61883-0 libimobiledevice6 libindicator3-7 libinput-bin libinput10
#   libip4tc0 libip6tc0 libiptc0 libisc-export160 libisc160 libisccc140
#   libisccfg140 libjack-jackd2-0 libjansson4 libjavascriptcoregtk-4.0-18
#   libjbig0 libjson-c3 libjson-glib-1.0-0 libjson-glib-1.0-common libkmod2
#   liblcms2-2 libldb1 liblightdm-gobject-1-0 libllvm5.0 liblocale-gettext-perl
#   libltdl7 liblwres141 liblzo2-2 libmagic-mgc libmagic1 libmbim-glib4
#   libmbim-proxy libmessaging-menu0 libmirclient9 libmircommon7 libmircore1
#   libmirprotobuf3 libmm-glib0 libmnl0 libmtdev1 libmtp-common libmtp-runtime
#   libmtp9 libndp0 libnetfilter-conntrack3 libnewt0.52 libnfnetlink0
#   libnl-3-200 libnl-genl-3-200 libnm-glib4 libnm-gtk0 libnm-util2 libnm0
#   libnma0 libnotify4 libnspr4 libnss-mdns libnss3 libntfs-3g872 liboauth0
#   libogg0 libopus0 liborc-0.4-0 libp11-kit-gnome-keyring
#   libpackagekit-glib2-18 libpam-cap libpam-gnome-keyring libpam-systemd
#   libpanel-applet3 libpango-1.0-0 libpangocairo-1.0-0 libpangoft2-1.0-0
#   libpangoxft-1.0-0 libparted2 libpcap0.8 libpci3 libpciaccess0 libpcsclite1
#   libphonenumber7 libpipeline1 libpixman-1-0 libplist3 libplymouth4
#   libpolkit-agent-1-0 libpolkit-backend-1-0 libpolkit-gobject-1-0
#   libprotobuf-lite10 libprotobuf10 libproxy1v5 libpulse-mainloop-glib0
#   libpulse0 libpulsedsp libpwquality-common libpwquality1 libqmi-glib5
#   libqmi-proxy libraw1394-11 librest-0.7-0 librsvg2-2 librsvg2-common
#   libsamplerate0 libseccomp2 libsecret-1-0 libsecret-common libsensors4
#   libshout3 libslang2 libsmbclient libsndfile1 libsoup-gnome2.4-1 libsoup2.4-1
#   libspeex1 libspeexdsp1 libstemmer0d libtag1v5 libtag1v5-vanilla libtalloc2
#   libtdb1 libtevent0 libtext-iconv-perl libthai-data libthai0 libtheora0
#   libtiff5 libtimezonemap-data libtimezonemap1 libtxc-dxtn-s2tc libudisks2-0
#   libunity-control-center1 libunity-settings-daemon1 libupower-glib3
#   liburl-dispatcher1 libusb-1.0-0 libusbmuxd4 libv4l-0 libv4lconvert0
#   libvdpau1 libvisual-0.4-0 libvorbis0a libvorbisenc2 libvorbisfile3 libvpx4
#   libwacom-bin libwacom-common libwacom2 libwavpack1 libwayland-client0
#   libwayland-cursor0 libwayland-egl1-mesa libwayland-server0 libwbclient0
#   libwebkit2gtk-4.0-37 libwebp6 libwebpdemux2 libwebrtc-audio-processing1
#   libwhoopsie-preferences0 libwhoopsie0 libwrap0 libx11-xcb1 libxapian30
#   libxatracker2 libxaw7 libxcb-dri2-0 libxcb-dri3-0 libxcb-glx0
#   libxcb-present0 libxcb-render0 libxcb-shape0 libxcb-shm0 libxcb-sync1
#   libxcb-util1 libxcb-xfixes0 libxcomposite1 libxcursor1 libxdamage1
#   libxfixes3 libxfont1 libxfont2 libxi6 libxinerama1 libxkbcommon0 libxkbfile1
#   libxklavier16 libxmu6 libxmuu1 libxnvctrl0 libxpm4 libxrandr2 libxshmfence1
#   libxslt1.1 libxt6 libxtables12 libxtst6 libxv1 libxvmc1 libxxf86dga1
#   libxxf86vm1 libyaml-0-2 libyelp0 libzeitgeist-2.0-0 lightdm
#   linux-headers-4.13.0-46 linux-headers-4.13.0-46-generic
#   linux-headers-generic lsb-release man-db mesa-vdpau-drivers
#   mobile-broadband-provider-info modemmanager mousetweaks nautilus-data
#   network-manager network-manager-gnome network-manager-pptp
#   notification-daemon ntfs-3g nvidia-384 nvidia-opencl-icd-384 nvidia-prime
#   nvidia-settings ocl-icd-libopencl1 p11-kit p11-kit-modules packagekit
#   packagekit-tools parted pciutils pinentry-gnome3 plymouth
#   plymouth-theme-ubuntu-text policykit-1 policykit-1-gnome ppp pptp-linux
#   psmisc pulseaudio pulseaudio-utils python-apt-common python-talloc
#   python3-apt python3-cairo python3-certifi python3-chardet python3-cups
#   python3-cupshelpers python3-dbus python3-gi python3-idna
#   python3-pkg-resources python3-requests python3-six python3-urllib3
#   python3-xdg python3-xkit rtkit samba-libs screen-resolution-extra
#   shared-mime-info sound-theme-freedesktop sudo system-config-printer
#   system-config-printer-common system-config-printer-udev systemd systemd-sysv
#   tcpd ubuntu-mono ubuntu-system-service ubuntu-touch-sounds udev udisks2
#   unity-control-center unity-greeter unity-settings-daemon upower
#   usb-modeswitch usb-modeswitch-data usbmuxd vdpau-driver-all wamerican
#   whoopsie-preferences wireless-regdb wpasupplicant x11-utils x11-xkb-utils
#   xauth xfonts-base xfonts-encodings xfonts-utils xkb-data xserver-common
#   xserver-xorg xserver-xorg-core xserver-xorg-input-all
#   xserver-xorg-input-libinput xserver-xorg-input-wacom xserver-xorg-legacy
#   xserver-xorg-video-all xserver-xorg-video-amdgpu xserver-xorg-video-ati
#   xserver-xorg-video-fbdev xserver-xorg-video-intel xserver-xorg-video-nouveau
#   xserver-xorg-video-qxl xserver-xorg-video-radeon xserver-xorg-video-vesa
#   xserver-xorg-video-vmware yelp yelp-xsl zeitgeist-core zenity zenity-common
# 0 upgraded, 584 newly installed, 0 to remove and 0 not upgraded.
# Need to get 244 MB of archives.
# After this operation, 1,133 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/main amd64 liblocale-gettext-perl amd64 1.07-3build2 [16.6 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 keyboard-configuration all 1.166ubuntu7 [622 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libapparmor1 amd64 2.11.0-2ubuntu17.1 [28.9 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libcap2 amd64 1:2.25-1.1 [13.2 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 libdevmapper1.02.1 amd64 2:1.02.137-2ubuntu3 [135 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful/main amd64 libcryptsetup4 amd64 2:1.7.3-4ubuntu1 [77.3 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 libip4tc0 amd64 1.6.1-2ubuntu1 [19.6 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful/main amd64 libkmod2 amd64 24-1ubuntu2 [40.1 kB]
# Get:9 http://archive.ubuntu.com/ubuntu artful/main amd64 libseccomp2 amd64 2.3.1-2.1ubuntu3 [37.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 systemd amd64 234-2ubuntu12.4 [2,782 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 systemd-sysv amd64 234-2ubuntu12.4 [11.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 udev amd64 234-2ubuntu12.4 [1,092 kB]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 libnfnetlink0 amd64 1.0.1-3 [13.3 kB]
# Get:14 http://archive.ubuntu.com/ubuntu artful/main amd64 groff-base amd64 1.22.3-9 [1,144 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful/main amd64 bsdmainutils amd64 9.0.12+nmu1ubuntu1 [179 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful/main amd64 libpipeline1 amd64 1.4.2-1 [25.2 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/main amd64 man-db amd64 2.7.6.1-2 [895 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful/main amd64 libfuse2 amd64 2.9.7-1ubuntu1 [80.9 kB]
# Get:19 http://archive.ubuntu.com/ubuntu artful/main amd64 fuse amd64 2.9.7-1ubuntu1 [24.5 kB]
# Get:20 http://archive.ubuntu.com/ubuntu artful/main amd64 libntfs-3g872 amd64 1:2016.2.22AR.2-2 [145 kB]
# Get:21 http://archive.ubuntu.com/ubuntu artful/main amd64 ntfs-3g amd64 1:2016.2.22AR.2-2 [380 kB]
# Get:22 http://archive.ubuntu.com/ubuntu artful/main amd64 fontconfig amd64 2.11.94-0ubuntu2 [177 kB]
# Get:23 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbusmenu-glib4 amd64 16.04.1+17.04.20170109.1-0ubuntu1 [40.8 kB]
# Get:24 http://archive.ubuntu.com/ubuntu artful/main amd64 libatk1.0-data all 2.26.0-2ubuntu1 [2,820 B]
# Get:25 http://archive.ubuntu.com/ubuntu artful/main amd64 libatk1.0-0 amd64 2.26.0-2ubuntu1 [44.2 kB]
# Get:26 http://archive.ubuntu.com/ubuntu artful/main amd64 libjbig0 amd64 2.1-3.1 [26.6 kB]
# Get:27 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libtiff5 amd64 4.0.8-5ubuntu0.1 [150 kB]
# Get:28 http://archive.ubuntu.com/ubuntu artful/main amd64 shared-mime-info amd64 1.8-1 [420 kB]
# Get:29 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgdk-pixbuf2.0-common all 2.36.11-1ubuntu0.1 [4,488 B]
# Get:30 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgdk-pixbuf2.0-0 amd64 2.36.11-1ubuntu0.1 [165 kB]
# Get:31 http://archive.ubuntu.com/ubuntu artful/main amd64 libthai-data all 0.1.26-3 [132 kB]
# Get:32 http://archive.ubuntu.com/ubuntu artful/main amd64 libdatrie1 amd64 0.2.10-5 [17.6 kB]
# Get:33 http://archive.ubuntu.com/ubuntu artful/main amd64 libthai0 amd64 0.1.26-3 [17.7 kB]
# Get:34 http://archive.ubuntu.com/ubuntu artful/main amd64 libpango-1.0-0 amd64 1.40.12-1 [152 kB]
# Get:35 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbusmenu-gtk3-4 amd64 16.04.1+17.04.20170109.1-0ubuntu1 [26.7 kB]
# Get:36 http://archive.ubuntu.com/ubuntu artful/main amd64 libdconf1 amd64 0.26.0-2 [33.0 kB]
# Get:37 http://archive.ubuntu.com/ubuntu artful/main amd64 dconf-service amd64 0.26.0-2 [27.2 kB]
# Get:38 http://archive.ubuntu.com/ubuntu artful/main amd64 dconf-gsettings-backend amd64 0.26.0-2 [20.0 kB]
# Get:39 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgtk-3-common all 3.22.25-0ubuntu0.1 [226 kB]
# Get:40 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbus-1-3 amd64 1.10.22-1ubuntu1 [165 kB]
# Get:41 http://archive.ubuntu.com/ubuntu artful/main amd64 libatspi2.0-0 amd64 2.26.0-2 [60.1 kB]
# Get:42 http://archive.ubuntu.com/ubuntu artful/main amd64 libatk-bridge2.0-0 amd64 2.26.0-1ubuntu1 [54.2 kB]
# Get:43 http://archive.ubuntu.com/ubuntu artful/main amd64 libpixman-1-0 amd64 0.34.0-1 [230 kB]
# Get:44 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-render0 amd64 1.12-1ubuntu1 [14.8 kB]
# Get:45 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-shm0 amd64 1.12-1ubuntu1 [5,482 B]
# Get:46 http://archive.ubuntu.com/ubuntu artful/main amd64 libcairo2 amd64 1.14.10-1ubuntu1 [558 kB]
# Get:47 http://archive.ubuntu.com/ubuntu artful/main amd64 libcairo-gobject2 amd64 1.14.10-1ubuntu1 [17.1 kB]
# Get:48 http://archive.ubuntu.com/ubuntu artful/main amd64 liblcms2-2 amd64 2.7-1ubuntu1 [137 kB]
# Get:49 http://archive.ubuntu.com/ubuntu artful/main amd64 libcolord2 amd64 1.3.3-2build1 [107 kB]
# Get:50 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libavahi-common-data amd64 0.6.32-1ubuntu1.1 [22.0 kB]
# Get:51 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libavahi-common3 amd64 0.6.32-1ubuntu1.1 [21.6 kB]
# Get:52 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libavahi-client3 amd64 0.6.32-1ubuntu1.1 [25.2 kB]
# Get:53 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libcups2 amd64 2.2.4-7ubuntu3.1 [209 kB]
# Get:54 http://archive.ubuntu.com/ubuntu artful/main amd64 libepoxy0 amd64 1.3.1-3 [176 kB]
# Get:55 http://archive.ubuntu.com/ubuntu artful/main amd64 libjson-glib-1.0-common all 1.2.8-1 [3,648 B]
# Get:56 http://archive.ubuntu.com/ubuntu artful/main amd64 libjson-glib-1.0-0 amd64 1.2.8-1 [60.4 kB]
# Get:57 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-system1.62.0 amd64 1.62.0+dfsg-4build3 [9,212 B]
# Get:58 http://archive.ubuntu.com/ubuntu artful/main amd64 libcapnp-0.5.3 amd64 0.5.3-2ubuntu2 [569 kB]
# Get:59 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-filesystem1.62.0 amd64 1.62.0+dfsg-4build3 [38.6 kB]
# Get:60 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircore1 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [31.5 kB]
# Get:61 http://archive.ubuntu.com/ubuntu artful/main amd64 libmircommon7 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [73.2 kB]
# Get:62 http://archive.ubuntu.com/ubuntu artful/main amd64 libprotobuf-lite10 amd64 3.0.0-9ubuntu5 [97.1 kB]
# Get:63 http://archive.ubuntu.com/ubuntu artful/main amd64 libmirprotobuf3 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [131 kB]
# Get:64 http://archive.ubuntu.com/ubuntu artful/main amd64 xkb-data all 2.19-1.1ubuntu1 [312 kB]
# Get:65 http://archive.ubuntu.com/ubuntu artful/main amd64 libxkbcommon0 amd64 0.7.1-2 [97.2 kB]
# Get:66 http://archive.ubuntu.com/ubuntu artful/main amd64 libmirclient9 amd64 0.28.0+17.10.20171011.1-0ubuntu1 [199 kB]
# Get:67 http://archive.ubuntu.com/ubuntu artful/main amd64 libgraphite2-3 amd64 1.3.10-2 [78.3 kB]
# Get:68 http://archive.ubuntu.com/ubuntu artful/main amd64 libharfbuzz0b amd64 1.4.2-1 [211 kB]
# Get:69 http://archive.ubuntu.com/ubuntu artful/main amd64 libpangoft2-1.0-0 amd64 1.40.12-1 [33.2 kB]
# Get:70 http://archive.ubuntu.com/ubuntu artful/main amd64 libpangocairo-1.0-0 amd64 1.40.12-1 [20.8 kB]
# Get:71 http://archive.ubuntu.com/ubuntu artful/main amd64 libproxy1v5 amd64 0.4.14-3 [50.8 kB]
# Get:72 http://archive.ubuntu.com/ubuntu artful/main amd64 glib-networking-common all 2.54.0-1 [2,960 B]
# Get:73 http://archive.ubuntu.com/ubuntu artful/main amd64 glib-networking-services amd64 2.54.0-1 [8,096 B]
# Get:74 http://archive.ubuntu.com/ubuntu artful/main amd64 gsettings-desktop-schemas all 3.24.1-1ubuntu1 [27.6 kB]
# Get:75 http://archive.ubuntu.com/ubuntu artful/main amd64 glib-networking amd64 2.54.0-1 [52.0 kB]
# Get:76 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libsoup2.4-1 amd64 2.60.1-1ubuntu0.1 [289 kB]
# Get:77 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libsoup-gnome2.4-1 amd64 2.60.1-1ubuntu0.1 [5,020 B]
# Get:78 http://archive.ubuntu.com/ubuntu artful/main amd64 librest-0.7-0 amd64 0.8.0-2 [31.8 kB]
# Get:79 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-client0 amd64 1.14.0-1ubuntu0.1 [22.5 kB]
# Get:80 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-cursor0 amd64 1.14.0-1ubuntu0.1 [9,890 B]
# Get:81 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-common all 2.4.83-1 [4,938 B]
# Get:82 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm2 amd64 2.4.83-1 [30.6 kB]
# Get:83 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-server0 amd64 1.14.0-1ubuntu0.1 [28.5 kB]
# Get:84 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgbm1 amd64 17.2.8-0ubuntu0~17.10.1 [24.4 kB]
# Get:85 http://archive.ubuntu.com/ubuntu artful/main amd64 libx11-xcb1 amd64 2:1.6.4-3 [9,626 B]
# Get:86 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri2-0 amd64 1.12-1ubuntu1 [6,838 B]
# Get:87 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-dri3-0 amd64 1.12-1ubuntu1 [5,156 B]
# Get:88 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-present0 amd64 1.12-1ubuntu1 [5,436 B]
# Get:89 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-sync1 amd64 1.12-1ubuntu1 [8,746 B]
# Get:90 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcb-xfixes0 amd64 1.12-1ubuntu1 [9,292 B]
# Get:91 http://archive.ubuntu.com/ubuntu artful/main amd64 libxshmfence1 amd64 1.2-1 [5,042 B]
# Get:92 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-amdgpu1 amd64 2.4.83-1 [18.5 kB]
# Get:93 http://archive.ubuntu.com/ubuntu artful/main amd64 libpciaccess0 amd64 0.13.4-1ubuntu1 [17.9 kB]
# Get:94 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-intel1 amd64 2.4.83-1 [59.7 kB]
# Get:95 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-nouveau2 amd64 2.4.83-1 [16.4 kB]
# Get:96 http://archive.ubuntu.com/ubuntu artful/main amd64 libdrm-radeon1 amd64 2.4.83-1 [21.6 kB]
# Get:97 http://archive.ubuntu.com/ubuntu artful/main amd64 libelf1 amd64 0.170-0.1 [44.3 kB]
# Get:98 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libglapi-mesa amd64 17.2.8-0ubuntu0~17.10.1 [22.2 kB]
# Get:99 http://archive.ubuntu.com/ubuntu artful/main amd64 libllvm5.0 amd64 1:5.0-3 [13.7 MB]
# Get:100 http://archive.ubuntu.com/ubuntu artful/main amd64 libsensors4 amd64 1:3.4.0-4 [28.8 kB]
# Get:101 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgl1-mesa-dri amd64 17.2.8-0ubuntu0~17.10.1 [5,707 kB]
# Get:102 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libegl1-mesa amd64 17.2.8-0ubuntu0~17.10.1 [85.3 kB]
# Get:103 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwayland-egl1-mesa amd64 17.2.8-0ubuntu0~17.10.1 [5,778 B]
# Get:104 http://archive.ubuntu.com/ubuntu artful/main amd64 libxcomposite1 amd64 1:0.4.4-2 [6,988 B]
# Get:105 http://archive.ubuntu.com/ubuntu artful/main amd64 libxfixes3 amd64 1:5.0.3-1 [10.8 kB]
# Get:106 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxcursor1 amd64 1:1.1.14-3ubuntu0.1 [19.8 kB]
# Get:107 http://archive.ubuntu.com/ubuntu artful/main amd64 libxdamage1 amd64 1:1.1.4-3 [6,934 B]
# Get:108 http://archive.ubuntu.com/ubuntu artful/main amd64 libxi6 amd64 2:1.7.9-1 [29.2 kB]
# Get:109 http://archive.ubuntu.com/ubuntu artful/main amd64 libxinerama1 amd64 2:1.1.3-1 [7,908 B]
# Get:110 http://archive.ubuntu.com/ubuntu artful/main amd64 libxrandr2 amd64 2:1.5.1-1 [18.1 kB]
# Get:111 http://archive.ubuntu.com/ubuntu artful/main amd64 hicolor-icon-theme all 0.17-1 [10.3 kB]
# Get:112 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 gtk-update-icon-cache amd64 3.22.25-0ubuntu0.1 [27.6 kB]
# Get:113 http://archive.ubuntu.com/ubuntu artful/main amd64 libcroco3 amd64 0.6.12-1 [81.3 kB]
# Get:114 http://archive.ubuntu.com/ubuntu artful/main amd64 librsvg2-2 amd64 2.40.18-1 [95.2 kB]
# Get:115 http://archive.ubuntu.com/ubuntu artful/main amd64 librsvg2-common amd64 2.40.18-1 [5,106 B]
# Get:116 http://archive.ubuntu.com/ubuntu artful/main amd64 humanity-icon-theme all 0.6.13 [1,288 kB]
# Get:117 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 ubuntu-mono all 16.10+17.10.20171115-0ubuntu1 [162 kB]
# Get:118 http://archive.ubuntu.com/ubuntu artful/main amd64 adwaita-icon-theme all 3.26.0-0ubuntu2 [3,452 kB]
# Get:119 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libgtk-3-0 amd64 3.22.25-0ubuntu0.1 [2,540 kB]
# Get:120 http://archive.ubuntu.com/ubuntu artful/main amd64 libindicator3-7 amd64 16.10.0+16.10.20160913-0ubuntu1 [26.1 kB]
# Get:121 http://archive.ubuntu.com/ubuntu artful/main amd64 libappindicator3-1 amd64 12.10.1+17.04.20170215-0ubuntu2 [19.2 kB]
# Get:122 http://archive.ubuntu.com/ubuntu artful/main amd64 libcdparanoia0 amd64 3.10.2+debian-11 [53.1 kB]
# Get:123 http://archive.ubuntu.com/ubuntu artful/main amd64 libdaemon0 amd64 0.14-6 [16.6 kB]
# Get:124 http://archive.ubuntu.com/ubuntu artful/main amd64 liblzo2-2 amd64 2.08-1.2 [48.7 kB]
# Get:125 http://archive.ubuntu.com/ubuntu artful/main amd64 libmtdev1 amd64 1.1.5-1ubuntu2 [13.8 kB]
# Get:126 http://archive.ubuntu.com/ubuntu artful/main amd64 libmtp-common all 1.1.13-1 [43.6 kB]
# Get:127 http://archive.ubuntu.com/ubuntu artful/main amd64 libusb-1.0-0 amd64 2:1.0.21-2 [43.3 kB]
# Get:128 http://archive.ubuntu.com/ubuntu artful/main amd64 libmtp9 amd64 1.1.13-1 [154 kB]
# Get:129 http://archive.ubuntu.com/ubuntu artful/main amd64 libogg0 amd64 1.3.2-1 [17.2 kB]
# Get:130 http://archive.ubuntu.com/ubuntu artful/main amd64 libspeex1 amd64 1.2~rc1.2-1ubuntu1 [51.3 kB]
# Get:131 http://archive.ubuntu.com/ubuntu artful/main amd64 libtheora0 amd64 1.1.1+dfsg.1-14 [170 kB]
# Get:132 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libvorbis0a amd64 1.3.5-4ubuntu0.2 [86.5 kB]
# Get:133 http://archive.ubuntu.com/ubuntu artful/main amd64 libshout3 amd64 2.3.1-3 [38.1 kB]
# Get:134 http://archive.ubuntu.com/ubuntu artful/main amd64 libstemmer0d amd64 0+svn585-1 [62.1 kB]
# Get:135 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libwbclient0 amd64 2:4.6.7+dfsg-1ubuntu3.2 [33.6 kB]
# Get:136 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86dga1 amd64 2:1.1.4-1 [13.7 kB]
# Get:137 http://archive.ubuntu.com/ubuntu artful/main amd64 libxxf86vm1 amd64 1:1.1.4-1 [10.6 kB]
# Get:138 http://archive.ubuntu.com/ubuntu artful/main amd64 dbus amd64 1.10.22-1ubuntu1 [144 kB]
# Get:139 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-data all 2.54.1-1ubuntu1 [4,250 B]
# Get:140 http://archive.ubuntu.com/ubuntu artful/main amd64 libglib2.0-bin amd64 2.54.1-1ubuntu1 [69.8 kB]
# Get:141 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libplymouth4 amd64 0.9.2-3ubuntu20 [85.2 kB]
# Get:142 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 plymouth amd64 0.9.2-3ubuntu20 [108 kB]
# Get:143 http://archive.ubuntu.com/ubuntu artful/universe amd64 lightdm amd64 1.24.0-0ubuntu1 [146 kB]
# Get:144 http://archive.ubuntu.com/ubuntu artful/main amd64 libtalloc2 amd64 2.1.9-2ubuntu1 [35.9 kB]
# Get:145 http://archive.ubuntu.com/ubuntu artful/main amd64 libtdb1 amd64 1.3.13-2build1 [39.1 kB]
# Get:146 http://archive.ubuntu.com/ubuntu artful/main amd64 libtevent0 amd64 0.9.31-1 [28.4 kB]
# Get:147 http://archive.ubuntu.com/ubuntu artful/main amd64 libldb1 amd64 2:1.1.29-2 [110 kB]
# Get:148 http://archive.ubuntu.com/ubuntu artful/main amd64 python-talloc amd64 2.1.9-2ubuntu1 [9,050 B]
# Get:149 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 samba-libs amd64 2:4.6.7+dfsg-1ubuntu3.2 [5,195 kB]
# Get:150 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libsmbclient amd64 2:4.6.7+dfsg-1ubuntu3.2 [54.2 kB]
# Get:151 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 distro-info-data all 0.36ubuntu0.2 [4,418 B]
# Get:152 http://archive.ubuntu.com/ubuntu artful/main amd64 dmsetup amd64 2:1.02.137-2ubuntu3 [71.9 kB]
# Get:153 http://archive.ubuntu.com/ubuntu artful/main amd64 eject amd64 2.1.5+deb1+cvs20081104-13.2 [22.8 kB]
# Get:154 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libmagic-mgc amd64 1:5.32-1ubuntu0.1 [184 kB]
# Get:155 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libmagic1 amd64 1:5.32-1ubuntu0.1 [68.4 kB]
# Get:156 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 file amd64 1:5.32-1ubuntu0.1 [22.0 kB]
# Get:157 http://archive.ubuntu.com/ubuntu artful/main amd64 libmnl0 amd64 1.0.4-2 [12.3 kB]
# Get:158 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 iproute2 amd64 4.9.0-1ubuntu2.1 [628 kB]
# Get:159 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisc-export160 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [155 kB]
# Get:160 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libdns-export162 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [671 kB]
# Get:161 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 isc-dhcp-client amd64 4.3.5-3ubuntu2.3 [244 kB]
# Get:162 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 isc-dhcp-common amd64 4.3.5-3ubuntu2.3 [45.8 kB]
# Get:163 http://archive.ubuntu.com/ubuntu artful/main amd64 kmod amd64 24-1ubuntu2 [88.7 kB]
# Get:164 http://archive.ubuntu.com/ubuntu artful/main amd64 libatm1 amd64 1:2.5.1-2 [21.7 kB]
# Get:165 http://archive.ubuntu.com/ubuntu artful/main amd64 libcap2-bin amd64 1:2.25-1.1 [20.5 kB]
# Get:166 http://archive.ubuntu.com/ubuntu artful/main amd64 libfribidi0 amd64 0.19.7-1 [25.1 kB]
# Get:167 http://archive.ubuntu.com/ubuntu artful/main amd64 libjson-c3 amd64 0.12.1-1.2 [21.5 kB]
# Get:168 http://archive.ubuntu.com/ubuntu artful/main amd64 libslang2 amd64 2.3.1-5ubuntu1 [422 kB]
# Get:169 http://archive.ubuntu.com/ubuntu artful/main amd64 libnewt0.52 amd64 0.52.18-3ubuntu3 [40.9 kB]
# Get:170 http://archive.ubuntu.com/ubuntu artful/main amd64 libpam-cap amd64 1:2.25-1.1 [7,190 B]
# Get:171 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpam-systemd amd64 234-2ubuntu12.4 [111 kB]
# Get:172 http://archive.ubuntu.com/ubuntu artful/main amd64 libtext-iconv-perl amd64 1.7-5build6 [13.0 kB]
# Get:173 http://archive.ubuntu.com/ubuntu artful/main amd64 libxtables12 amd64 1.6.1-2ubuntu1 [27.8 kB]
# Get:174 http://archive.ubuntu.com/ubuntu artful/main amd64 libyaml-0-2 amd64 0.1.7-2ubuntu3 [47.2 kB]
# Get:175 http://archive.ubuntu.com/ubuntu artful/main amd64 lsb-release all 9.20160110ubuntu5 [11.1 kB]
# Get:176 http://archive.ubuntu.com/ubuntu artful/main amd64 sudo amd64 1.8.20p2-1ubuntu1 [415 kB]
# Get:177 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libaccountsservice0 amd64 0.6.42-0ubuntu3.1 [70.2 kB]
# Get:178 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpolkit-gobject-1-0 amd64 0.105-18ubuntu0.1 [37.4 kB]
# Get:179 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 accountsservice amd64 0.6.42-0ubuntu3.1 [59.8 kB]
# Get:180 http://archive.ubuntu.com/ubuntu artful/main amd64 libgeoip1 amd64 1.6.11-2ubuntu1 [71.7 kB]
# Get:181 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisc160 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [219 kB]
# Get:182 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libdns162 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [883 kB]
# Get:183 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisccc140 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [16.6 kB]
# Get:184 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libisccfg140 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [40.9 kB]
# Get:185 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libbind9-140 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [23.9 kB]
# Get:186 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 liblwres141 amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [34.5 kB]
# Get:187 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 bind9-host amd64 1:9.10.3.dfsg.P4-12.6ubuntu1.1 [50.1 kB]
# Get:188 http://archive.ubuntu.com/ubuntu artful/main amd64 dosfstools amd64 4.1-1 [58.1 kB]
# Get:189 http://archive.ubuntu.com/ubuntu artful/main amd64 geoip-database all 20170912-1 [2,225 kB]
# Get:190 http://archive.ubuntu.com/ubuntu artful/main amd64 gettext-base amd64 0.19.8.1-4ubuntu1 [49.4 kB]
# Get:191 http://archive.ubuntu.com/ubuntu artful/main amd64 libgirepository-1.0-1 amd64 1.54.1-1 [82.1 kB]
# Get:192 http://archive.ubuntu.com/ubuntu artful/main amd64 gir1.2-glib-2.0 amd64 1.54.1-1 [131 kB]
# Get:193 http://archive.ubuntu.com/ubuntu artful/main amd64 libip6tc0 amd64 1.6.1-2ubuntu1 [19.9 kB]
# Get:194 http://archive.ubuntu.com/ubuntu artful/main amd64 libiptc0 amd64 1.6.1-2ubuntu1 [9,254 B]
# Get:195 http://archive.ubuntu.com/ubuntu artful/main amd64 libnetfilter-conntrack3 amd64 1.0.6-2 [37.8 kB]
# Get:196 http://archive.ubuntu.com/ubuntu artful/main amd64 iptables amd64 1.6.1-2ubuntu1 [269 kB]
# Get:197 http://archive.ubuntu.com/ubuntu artful/main amd64 iso-codes all 3.75-1 [2,339 kB]
# Get:198 http://archive.ubuntu.com/ubuntu artful/main amd64 libdbus-glib-1-2 amd64 0.108-2 [67.1 kB]
# Get:199 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libparted2 amd64 3.2-18ubuntu0.1 [123 kB]
# Get:200 http://archive.ubuntu.com/ubuntu artful/main amd64 libpcap0.8 amd64 1.8.1-5ubuntu1 [118 kB]
# Get:201 http://archive.ubuntu.com/ubuntu artful/main amd64 libpci3 amd64 1:3.5.2-1ubuntu1 [24.1 kB]
# Get:202 http://archive.ubuntu.com/ubuntu artful/main amd64 libxmuu1 amd64 2:1.1.2-2 [9,674 B]
# Get:203 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 parted amd64 3.2-18ubuntu0.1 [42.3 kB]
# Get:204 http://archive.ubuntu.com/ubuntu artful/main amd64 pciutils amd64 1:3.5.2-1ubuntu1 [247 kB]
# Get:205 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 plymouth-theme-ubuntu-text amd64 0.9.2-3ubuntu20 [8,968 B]
# Get:206 http://archive.ubuntu.com/ubuntu artful/main amd64 psmisc amd64 23.1-1 [51.5 kB]
# Get:207 http://archive.ubuntu.com/ubuntu artful/main amd64 python-apt-common all 1.4.0~beta3build2 [17.1 kB]
# Get:208 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-apt amd64 1.4.0~beta3build2 [141 kB]
# Get:209 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-dbus amd64 1.2.4-1build3 [84.1 kB]
# Get:210 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-gi amd64 3.24.1-2build1 [153 kB]
# Get:211 http://archive.ubuntu.com/ubuntu artful/main amd64 xauth amd64 1:1.0.9-1ubuntu2 [22.7 kB]
# Get:212 http://archive.ubuntu.com/ubuntu artful/main amd64 acpid amd64 1:2.0.28-1ubuntu1 [36.5 kB]
# Get:213 http://archive.ubuntu.com/ubuntu artful/main amd64 libgee-0.8-2 amd64 0.20.0-1 [211 kB]
# Get:214 http://archive.ubuntu.com/ubuntu artful/universe amd64 libunity-control-center1 amd64 15.04.0+17.10.20170930-0ubuntu1 [80.6 kB]
# Get:215 http://archive.ubuntu.com/ubuntu artful/main amd64 libwhoopsie-preferences0 amd64 0.19 [13.9 kB]
# Get:216 http://archive.ubuntu.com/ubuntu artful/main amd64 libzeitgeist-2.0-0 amd64 1.0-0ubuntu4 [115 kB]
# Get:217 http://archive.ubuntu.com/ubuntu artful/main amd64 libdee-1.0-4 amd64 1.2.7+17.10.20170616-0ubuntu1 [75.7 kB]
# Get:218 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libxapian30 amd64 1.4.4-2ubuntu0.1 [628 kB]
# Get:219 http://archive.ubuntu.com/ubuntu artful/main amd64 zeitgeist-core amd64 1.0-0ubuntu4 [134 kB]
# Get:220 http://archive.ubuntu.com/ubuntu artful/main amd64 libwhoopsie0 amd64 0.2.58 [9,502 B]
# Get:221 http://archive.ubuntu.com/ubuntu artful/main amd64 whoopsie-preferences amd64 0.19 [8,728 B]
# Get:222 http://archive.ubuntu.com/ubuntu artful/universe amd64 activity-log-manager amd64 0.9.7-0ubuntu26 [93.8 kB]
# Get:223 http://archive.ubuntu.com/ubuntu artful/main amd64 apg amd64 2.2.3.dfsg.1-4 [50.2 kB]
# Get:224 http://archive.ubuntu.com/ubuntu artful/main amd64 libaspell15 amd64 0.60.7~20110707-4 [309 kB]
# Get:225 http://archive.ubuntu.com/ubuntu artful/main amd64 emacsen-common all 2.0.8 [17.6 kB]
# Get:226 http://archive.ubuntu.com/ubuntu artful/main amd64 dictionaries-common all 1.27.2 [186 kB]
# Get:227 http://archive.ubuntu.com/ubuntu artful/main amd64 aspell amd64 0.60.7~20110707-4 [77.1 kB]
# Get:228 http://archive.ubuntu.com/ubuntu artful/main amd64 aspell-en all 2017.08.24-0-0.1 [298 kB]
# Get:229 http://archive.ubuntu.com/ubuntu artful/main amd64 libxtst6 amd64 2:1.2.3-1 [12.8 kB]
# Get:230 http://archive.ubuntu.com/ubuntu artful/main amd64 at-spi2-core amd64 2.26.0-2 [48.6 kB]
# Get:231 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libavahi-core7 amd64 0.6.32-1ubuntu1.1 [81.4 kB]
# Get:232 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 avahi-daemon amd64 0.6.32-1ubuntu1.1 [60.9 kB]
# Get:233 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 avahi-utils amd64 0.6.32-1ubuntu1.1 [24.8 kB]
# Get:234 http://archive.ubuntu.com/ubuntu artful/main amd64 bluez amd64 5.46-0ubuntu3 [901 kB]
# Get:235 http://archive.ubuntu.com/ubuntu artful/main amd64 libical2 amd64 2.0.0-0.5 [194 kB]
# Get:236 http://archive.ubuntu.com/ubuntu artful/main amd64 bluez-obexd amd64 5.46-0ubuntu3 [167 kB]
# Get:237 http://archive.ubuntu.com/ubuntu artful/main amd64 cheese-common all 3.26.0-0ubuntu1 [719 kB]
# Get:238 http://archive.ubuntu.com/ubuntu artful/main amd64 libcrack2 amd64 2.9.2-5build1 [28.0 kB]
# Get:239 http://archive.ubuntu.com/ubuntu artful/main amd64 cracklib-runtime amd64 2.9.2-5build1 [134 kB]
# Get:240 http://archive.ubuntu.com/ubuntu artful/main amd64 libnl-3-200 amd64 3.2.29-0ubuntu3 [52.8 kB]
# Get:241 http://archive.ubuntu.com/ubuntu artful/main amd64 libnl-genl-3-200 amd64 3.2.29-0ubuntu3 [11.2 kB]
# Get:242 http://archive.ubuntu.com/ubuntu artful/main amd64 wireless-regdb all 2016.06.10-0ubuntu1 [8,824 B]
# Get:243 http://archive.ubuntu.com/ubuntu artful/main amd64 iw amd64 4.9-0.1 [70.4 kB]
# Get:244 http://archive.ubuntu.com/ubuntu artful/main amd64 crda amd64 3.18-0ubuntu1 [63.4 kB]
# Get:245 http://archive.ubuntu.com/ubuntu artful/main amd64 dbus-user-session all 1.10.22-1ubuntu1 [9,278 B]
# Get:246 http://archive.ubuntu.com/ubuntu artful/main amd64 dbus-x11 amd64 1.10.22-1ubuntu1 [22.1 kB]
# Get:247 http://archive.ubuntu.com/ubuntu artful/main amd64 dconf-cli amd64 0.26.0-2 [22.7 kB]
# Get:248 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 desktop-file-utils amd64 0.23-1ubuntu3.17.10.1 [51.3 kB]
# ...
# Setting up gettext-base (0.19.8.1-4ubuntu1) ...
# Setting up libtxc-dxtn-s2tc:amd64 (1.0+git20151227-2) ...
# update-alternatives: using /usr/lib/x86_64-linux-gnu/s2tc/libtxc_dxtn.so to provide /usr/lib/x86_64-linux-gnu/libtxc_dxtn.so (libtxc-dxtn-x86_64-linux-gnu) in auto mode
# 7Progress: [ 67%] [######################################....................] 8Setting up libstemmer0d:amd64 (0+svn585-1) ...
# Setting up libp11-kit-gnome-keyring:amd64 (3.20.1-1ubuntu1) ...
# Setting up libpipeline1:amd64 (1.4.2-1) ...
# Setting up libc6-i386 (2.26-0ubuntu2.1) ...
# Setting up libiec61883-0:amd64 (1.2.0-2) ...
# Setting up libglapi-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up libpackagekit-glib2-18:amd64 (1.1.7-1ubuntu0.1) ...
# Setting up libxcb-util1:amd64 (0.4.0-0ubuntu3) ...
# Setting up libspeex1:amd64 (1.2~rc1.2-1ubuntu1) ...
# Setting up apg (2.2.3.dfsg.1-4) ...
# Setting up python3-pkg-resources (36.2.7-2) ...
# Setting up libgeoip1:amd64 (1.6.11-2ubuntu1) ...
# Setting up libxvmc1:amd64 (2:1.0.10-1) ...
# Setting up parted (3.2-18ubuntu0.1) ...
# Setting up lsb-release (9.20160110ubuntu5) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libcdparanoia0:amd64 (3.10.2+debian-11) ...
# Setting up linux-headers-4.13.0-46 (4.13.0-46.51) ...
# Setting up libnspr4:amd64 (2:4.16-1ubuntu2) ...
# Setting up xfonts-encodings (1:1.0.4-2) ...
# Setting up libgphoto2-l10n (2.5.14-1) ...
# Setting up libgirepository-1.0-1:amd64 (1.54.1-1) ...
# Setting up libxmuu1:amd64 (2:1.1.2-2) ...
# Setting up libvpx4:amd64 (1.6.1-3) ...
# Setting up libmtp-common (1.1.13-1) ...
# Setting up libntfs-3g872 (1:2016.2.22AR.2-2) ...
# Setting up libgck-1-0:amd64 (3.20.0-5.1ubuntu1) ...
# Setting up libopus0:amd64 (1.1.2-1ubuntu1) ...
# Setting up libxtst6:amd64 (2:1.2.3-1) ...
# Setting up libmagic-mgc (1:5.32-1ubuntu0.1) ...
# Setting up libasound2:amd64 (1.1.3-5) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up gnome-control-center-faces (1:3.26.2-0ubuntu0.2) ...
# Setting up libmagic1:amd64 (1:5.32-1ubuntu0.1) ...
# Setting up libdrm-common (2.4.83-1) ...
# Setting up libjson-glib-1.0-0:amd64 (1.2.8-1) ...
# Setting up libgcr-3-common (3.20.0-5.1ubuntu1) ...
# Setting up libgraphite2-3:amd64 (1.3.10-2) ...
# Setting up usb-modeswitch-data (20170806-1) ...
# Setting up libcroco3:amd64 (0.6.12-1) ...
# Setting up libxcb-sync1:amd64 (1.12-1ubuntu1) ...
# Setting up linux-headers-4.13.0-46-generic (4.13.0-46.51) ...
# Examining /etc/kernel/header_postinst.d.
# Setting up xauth (1:1.0.9-1ubuntu2) ...
# Setting up libxslt1.1:amd64 (1.1.29-2.1ubuntu1) ...
# Setting up libaccountsservice0:amd64 (0.6.42-0ubuntu3.1) ...
# Setting up libprotobuf10:amd64 (3.0.0-9ubuntu5) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up mobile-broadband-provider-info (20170903-1) ...
# Setting up libogg0:amd64 (1.3.2-1) ...
# Setting up libatk1.0-data (2.26.0-2ubuntu1) ...
# Setting up libfcitx-config4:amd64 (1:4.2.9.1-6) ...
# Setting up libgeonames-common (0.2+17.04.20170220-0ubuntu1) ...
# Setting up libhyphen0:amd64 (2.8.8-5) ...
# Setting up libyaml-0-2:amd64 (0.1.7-2ubuntu3) ...
# Setting up libx11-xcb1:amd64 (2:1.6.4-3) ...
# Setting up libpixman-1-0:amd64 (0.34.0-1) ...
# Setting up acpid (1:2.0.28-1ubuntu1) ...
# Created symlink /etc/systemd/system/sockets.target.wants/acpid.socket → /lib/systemd/system/acpid.socket.
# Created symlink /etc/systemd/system/paths.target.wants/acpid.path → /lib/systemd/system/acpid.path.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up gir1.2-glib-2.0:amd64 (1.54.1-1) ...
# Setting up libxcursor1:amd64 (1:1.1.14-3ubuntu0.1) ...
# Setting up ubuntu-touch-sounds (15.08) ...
# Setting up dkms (2.3-3ubuntu3) ...
# Setting up libglib2.0-data (2.54.1-1ubuntu1) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up p11-kit-modules:amd64 (0.23.7-3) ...
# Setting up libdbusmenu-glib4:amd64 (16.04.1+17.04.20170109.1-0ubuntu1) ...
# Setting up libusb-1.0-0:amd64 (2:1.0.21-2) ...
# Setting up libxxf86dga1:amd64 (2:1.1.4-1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up libmm-glib0:amd64 (1.6.8-1) ...
# Setting up libmessaging-menu0:amd64 (13.10.1+17.04.20170120-0ubuntu2) ...
# Setting up libatm1:amd64 (1:2.5.1-2) ...
# Setting up libepoxy0:amd64 (1.3.1-3) ...
# Setting up libxtables12:amd64 (1.6.1-2ubuntu1) ...
# Setting up udev (234-2ubuntu12.4) ...
# Adding group `input' (GID 107) ...
# Done.
# invoke-rc.d: could not determine current runlevel
# invoke-rc.d: policy-rc.d denied execution of start.
# Setting up python3-chardet (3.0.4-1) ...
# Setting up libgnome-menu-3-0:amd64 (3.13.3-6ubuntu5) ...
# Setting up indicator-common (16.10.0+16.10.20160913-0ubuntu1) ...
# Setting up libatk1.0-0:amd64 (2.26.0-2ubuntu1) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up libtext-iconv-perl (1.7-5build6) ...
# Setting up zeitgeist-core (1.0-0ubuntu4) ...
# Setting up libfakeroot:amd64 (1.21-1ubuntu2) ...
# Setting up gdisk (1.0.1-1build1) ...
# Setting up ntfs-3g (1:2016.2.22AR.2-2) ...
# Processing triggers for systemd (234-2ubuntu12.4) ...
# Setting up libltdl7:amd64 (2.4.6-2) ...
# Setting up libpwquality-common (1.4.0-1) ...
# Setting up liblwres141:amd64 (1:9.10.3.dfsg.P4-12.6ubuntu1.1) ...
# Setting up libmtp9:amd64 (1.1.13-1) ...
# Setting up libmtdev1:amd64 (1.1.5-1ubuntu2) ...
# Setting up libplymouth4:amd64 (0.9.2-3ubuntu20) ...
# Setting up libupower-glib3:amd64 (0.99.6-1) ...
# Setting up libavc1394-0:amd64 (0.5.4-4) ...
# Setting up zenity-common (3.24.0-1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up libvisual-0.4-0:amd64 (0.4.0-10) ...
# Setting up libfontenc1:amd64 (1:1.1.3-1) ...
# Setting up libdconf1:amd64 (0.26.0-2) ...
# Setting up libxcomposite1:amd64 (1:0.4.4-2) ...
# Setting up libfribidi0:amd64 (0.19.7-1) ...
# Setting up libxcb-shm0:amd64 (1.12-1ubuntu1) ...
# Setting up liblocale-gettext-perl (1.07-3build2) ...
# Setting up dmsetup (2:1.02.137-2ubuntu3) ...
# Setting up libxpm4:amd64 (1:3.5.12-1) ...
# Setting up libcrack2:amd64 (2.9.2-5build1) ...
# Setting up libxt6:amd64 (1:1.1.5-1) ...
# Setting up libpciaccess0:amd64 (0.13.4-1ubuntu1) ...
# Setting up libxcb-shape0:amd64 (1.12-1ubuntu1) ...
# Setting up libxv1:amd64 (2:1.0.11-1) ...
# Setting up libsensors4:amd64 (1:3.4.0-4) ...
# 7Progress: [ 74%] [##########################################................] 8Setting up shared-mime-info (1.8-1) ...
# Setting up libxkbcommon0:amd64 (0.7.1-2) ...
# Setting up gir1.2-packagekitglib-1.0 (1.1.7-1ubuntu0.1) ...
# Setting up libnfnetlink0:amd64 (1.0.1-3) ...
# Setting up libgudev-1.0-0:amd64 (1:232-1) ...
# Setting up python3-urllib3 (1.21.1-1) ...
# Setting up libtalloc2:amd64 (2.1.9-2ubuntu1) ...
# Setting up libjavascriptcoregtk-4.0-18:amd64 (2.20.3-0ubuntu0.17.10.1) ...
# Setting up yelp-xsl (3.20.1-2) ...
# Setting up libibus-1.0-5:amd64 (1.5.14-2ubuntu1) ...
# Setting up libcdio-paranoia1:amd64 (0.83-4.2ubuntu1) ...
# Setting up liborc-0.4-0:amd64 (1:0.4.27-1) ...
# Setting up gnome-menus (3.13.3-6ubuntu5) ...
# Setting up libcolord2:amd64 (1.3.3-2build1) ...
# 7Progress: [ 75%] [###########################################...............] 8Setting up libthai-data (0.1.26-3) ...
# Setting up ocl-icd-libopencl1:amd64 (2.2.11-1ubuntu1) ...
# Setting up libxxf86vm1:amd64 (1:1.1.4-1) ...
# Setting up libndp0:amd64 (1.6-1) ...
# Setting up wamerican (2017.01.22-1) ...
# Setting up liburl-dispatcher1:amd64 (0.1+17.04.20170328-0ubuntu3) ...
# Setting up bsdmainutils (9.0.12+nmu1ubuntu1) ...
# update-alternatives: using /usr/bin/bsd-write to provide /usr/bin/write (write) in auto mode
# update-alternatives: using /usr/bin/bsd-from to provide /usr/bin/from (from) in auto mode
# Setting up libsamplerate0:amd64 (0.1.9-1) ...
# Setting up libnl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up libpci3:amd64 (1:3.5.2-1ubuntu1) ...
# Setting up libgdata-common (0.17.9-1) ...
# Setting up libvorbis0a:amd64 (1.3.5-4ubuntu0.2) ...
# Setting up libusbmuxd4:amd64 (1.0.10-3) ...
# Setting up iputils-arping (3:20161105-1ubuntu2) ...
# Setting up libprotobuf-lite10:amd64 (3.0.0-9ubuntu5) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up hicolor-icon-theme (0.17-1) ...
# Setting up libsecret-1-0:amd64 (0.18.5-3.1ubuntu2) ...
# Setting up libglib2.0-bin (2.54.1-1ubuntu1) ...
# Setting up libslang2:amd64 (2.3.1-5ubuntu1) ...
# Setting up libmnl0:amd64 (1.0.4-2) ...
# Setting up libgles2-mesa:amd64 (17.2.8-0ubuntu0~17.10.1) ...
# Setting up gnome-desktop3-data (3.26.2-0ubuntu0.1) ...
# Setting up libexif12:amd64 (0.6.21-2.1) ...
# Setting up libimobiledevice6:amd64 (1.2.0+dfsg-3.1ubuntu3) ...
# Setting up libwayland-cursor0:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up libwhoopsie0:amd64 (0.2.58) ...
# Setting up bbswitch-dkms (0.8-4ubuntu1) ...
# Loading new bbswitch-0.8 DKMS files...
# It is likely that 4.14.33+ belongs to a chroot's host
# Building for 4.13.0-46-generic
# Building initial module for 4.13.0-46-generic
# Done.
#
# bbswitch:
# Running module version sanity check.
#  - Original module
#    - No original module exists within this kernel
#  - Installation
#    - Installing to /lib/modules/4.13.0-46-generic/updates/dkms/
#
# depmod...
#
# DKMS: install completed.
# Setting up libtimezonemap-data (0.4.5) ...
# Setting up libxnvctrl0 (384.69-0ubuntu1) ...
# Setting up libspeexdsp1:amd64 (1.2~rc1.2-1ubuntu1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libxrandr2:amd64 (2:1.5.1-1) ...
# Setting up libpolkit-gobject-1-0:amd64 (0.105-18ubuntu0.1) ...
# Setting up libdbus-1-3:amd64 (1.10.22-1ubuntu1) ...
# Setting up libip6tc0:amd64 (1.6.1-2ubuntu1) ...
# Setting up libboost-system1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libdv4:amd64 (1.0.0-11) ...
# Setting up libtag1v5-vanilla:amd64 (1.11.1+dfsg.1-0.2) ...
# Setting up lib32gcc1 (1:7.2.0-8ubuntu3.2) ...
# Setting up fontconfig (2.11.94-0ubuntu2) ...
# Regenerating fonts cache... done.
# Setting up liblzo2-2:amd64 (2.08-1.2) ...
# Setting up libwrap0:amd64 (7.6.q-26) ...
# Setting up libavahi-common-data:amd64 (0.6.32-1ubuntu1.1) ...
# Setting up eject (2.1.5+deb1+cvs20081104-13.2) ...
# Setting up python3-xkit (0.5.0ubuntu2) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libpcap0.8:amd64 (1.8.1-5ubuntu1) ...
# Setting up libwayland-server0:amd64 (1.14.0-1ubuntu0.1) ...
# Setting up libwebp6:amd64 (0.6.0-3) ...
# Setting up linux-headers-generic (4.13.0.46.49) ...
# Setting up python-talloc (2.1.9-2ubuntu1) ...
# Setting up libvorbisfile3:amd64 (1.3.5-4ubuntu0.2) ...
# Setting up libcairo2:amd64 (1.14.10-1ubuntu1) ...
# Setting up usbmuxd (1.1.0-2build1) ...
# Warning: The home dir /var/lib/usbmux you specified can't be accessed: No such file or directory
# Adding system user `usbmux' (UID 105) ...
# Adding new user `usbmux' (UID 105) with group `plugdev' ...
# Not creating home directory `/var/lib/usbmux'.
# Setting up libgtop-2.0-11:amd64 (2.38.0-1) ...
# Setting up keyboard-configuration (1.166ubuntu7) ...
# Setting up libgphoto2-port12:amd64 (2.5.14-1) ...
# Setting up gir1.2-ibus-1.0:amd64 (1.5.14-2ubuntu1) ...
# Setting up gir1.2-atk-1.0:amd64 (2.26.0-2ubuntu1) ...
# Setting up libnetfilter-conntrack3:amd64 (1.0.6-2) ...
# Setting up libmbim-glib4:amd64 (1.14.2-1) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libtag1v5:amd64 (1.11.1+dfsg.1-0.2) ...
# Setting up libisc160:amd64 (1:9.10.3.dfsg.P4-12.6ubuntu1.1) ...
# Setting up im-config (0.32-1ubuntu3) ...
# Setting up libgstreamer1.0-0:amd64 (1.12.3-1) ...
# Setcap worked! gst-ptp-helper is not suid!
# Setting up libwacom2:amd64 (0.24-1) ...
# Setting up ppp (2.4.7-1+2ubuntu1) ...
# Created symlink /etc/systemd/system/multi-user.target.wants/pppd-dns.service → /lib/systemd/system/pppd-dns.service.
# Setting up libappstream4:amd64 (0.11.3-1) ...
# Setting up libgcr-base-3-1:amd64 (3.20.0-5.1ubuntu1) ...
# Setting up gvfs-common (1.34.1-1ubuntu1) ...
# Setting up libcanberra0:amd64 (0.30-3ubuntu1) ...
# Setting up dconf-service (0.26.0-2) ...
# Setting up libv4l-0:amd64 (1.12.5-1) ...
# Setting up dictionaries-common (1.27.2) ...
# Setting up libarchive13:amd64 (3.2.2-3.1) ...
# Setting up libboost-thread1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libdbus-glib-1-2:amd64 (0.108-2) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up gir1.2-freedesktop:amd64 (1.54.1-1) ...
# Setting up libpolkit-agent-1-0:amd64 (0.105-18ubuntu0.1) ...
# Setting up libmirprotobuf3:amd64 (0.28.0+17.10.20171011.1-0ubuntu1) ...
# Setting up gir1.2-polkit-1.0 (0.105-18ubuntu0.1) ...
# Setting up libatspi2.0-0:amd64 (2.26.0-2) ...
# Setting up p11-kit (0.23.7-3) ...
# Setting up libnm0:amd64 (1.8.4-1ubuntu3) ...
# Setting up at-spi2-core (2.26.0-2) ...
# Setting up libgdk-pixbuf2.0-0:amd64 (2.36.11-1ubuntu0.1) ...
# Setting up libcairo-gobject2:amd64 (1.14.10-1ubuntu1) ...
# Setting up libflac8:amd64 (1.3.2-1) ...
# Setting up pptp-linux (1.9.0+ds-1) ...
# Setting up libgdk-pixbuf2.0-bin (2.36.11-1ubuntu0.1) ...
# Setting up libgd3:amd64 (2.2.5-3) ...
# Setting up gir1.2-gdkpixbuf-2.0:amd64 (2.36.11-1ubuntu0.1) ...
# 7Progress: [ 81%] [##############################################............] 8Setting up libnl-genl-3-200:amd64 (3.2.29-0ubuntu3) ...
# Setting up whoopsie-preferences (0.19) ...
# Setting up libnss3:amd64 (2:3.32-1ubuntu3) ...
# Setting up libxfont2:amd64 (1:2.0.1-3ubuntu1.1) ...
# Setting up libharfbuzz0b:amd64 (1.4.2-1) ...
# Setting up dconf-cli (0.26.0-2) ...
# Setting up libfcitx-gclient0:amd64 (1:4.2.9.1-6) ...
# Setting up libthai0:amd64 (0.1.26-3) ...
# Setting up python3-gi (3.24.1-2build1) ...
# Setting up file (1:5.32-1ubuntu0.1) ...
# Setting up fakeroot (1.21-1ubuntu2) ...
# update-alternatives: using /usr/bin/fakeroot-sysv to provide /usr/bin/fakeroot (fakeroot) in auto mode
# Setting up iproute2 (4.9.0-1ubuntu2.1) ...
# Setting up libinput-bin (1.8.4-0ubuntu0.17.10.1) ...
# Setting up tcpd (7.6.q-26) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libmtp-runtime (1.1.13-1) ...
# Setting up libmbim-proxy (1.14.2-1) ...
# Setting up libxfont1:amd64 (1:1.5.2-4ubuntu1.1) ...
# Setting up libxmu6:amd64 (2:1.1.2-2) ...
# Setting up libdrm2:amd64 (2.4.83-1) ...
# Setting up isc-dhcp-client (4.3.5-3ubuntu2.3) ...
# Setting up libgeonames0:amd64 (0.2+17.04.20170220-0ubuntu1) ...
# Setting up plymouth (0.9.2-3ubuntu20) ...
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# update-rc.d: warning: start and stop actions are no longer supported; falling back to defaults
# Setting up liboauth0:amd64 (1.0.3-1) ...
# Setting up libtevent0:amd64 (0.9.31-1) ...
# Setting up libpwquality1:amd64 (1.4.0-1) ...
# Setting up libdrm-intel1:amd64 (2.4.83-1) ...
# Setting up libisccc140:amd64 (1:9.10.3.dfsg.P4-12.6ubuntu1.1) ...
# Setting up libwacom-bin (0.24-1) ...
# Setting up gtk-update-icon-cache (3.22.25-0ubuntu0.1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up usb-modeswitch (2.5.1+repack0-1ubuntu1) ...
# Setting up libpolkit-backend-1-0:amd64 (0.105-18ubuntu0.1) ...
# Setting up libaa1:amd64 (1.4p5-44build1) ...
# Setting up gir1.2-secret-1:amd64 (0.18.5-3.1ubuntu2) ...
# Setting up iptables (1.6.1-2ubuntu1) ...
# Setting up gvfs-libs:amd64 (1.34.1-1ubuntu1) ...
# Setting up libphonenumber7:amd64 (7.1.0-5ubuntu2) ...
# Setting up rtkit (0.11-5) ...
# Setting up bluez-obexd (5.46-0ubuntu3) ...
# Setting up libpango-1.0-0:amd64 (1.40.12-1) ...
# Setting up libboost-filesystem1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Setting up libatk-bridge2.0-0:amd64 (2.26.0-1ubuntu1) ...
# Setting up libjack-jackd2-0:amd64 (1.9.10+20150825git1ed50c92~dfsg-5ubuntu1) ...
# Setting up python3-requests (2.18.1-1) ...
# Setting up dnsmasq-base (2.78-1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up libwebpdemux2:amd64 (0.6.0-3) ...
# Setting up pciutils (1:3.5.2-1ubuntu1) ...
# Setting up man-db (2.7.6.1-2) ...
# Building database of manual pages ...

# %%
# !make all
# Out:
# nvcc -g -std=c++11 -I`python -c "import tensorflow; print(tensorflow.sysconfig.get_include())"` -I"/usr/local/cuda/include" -DGOOGLE_CUDA=1 -D_MWAITXINTRIN_H_INCLUDED -D_FORCE_INLINES -D__STRICT_ANSI__ -D_GLIBCXX_USE_CXX11_ABI=0 -c src/ops/preprocessing/kernels/data_augmentation.cu.cc -x cu -Xcompiler -fPIC  -o src/ops/build/data_augmentation.o
# /bin/sh: 1: nvcc: not found
# Makefile:62: recipe for target 'preprocessing' failed
# make: *** [preprocessing] Error 127

# %%
# !cat src/flownet2/test.py

# %% [markdown]
# #Motion net(Failed experiment)(Left as future work)

# %%
# !apt install -y caffe-cuda
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   caffe-tools-cuda cython3 fonts-lyx gdal-data javascript-common libarmadillo7
#   libarpack2 libblosc1 libboost-python1.62.0 libboost-system1.62.0
#   libboost-thread1.62.0 libcaffe-cuda1 libdap25 libdapclient6v5 libepsilon1
#   libfreexl1 libfyba0 libgdal20 libgeos-3.5.1 libgeos-c1v5 libgeotiff2
#   libgflags2.2 libgif7 libgoogle-glog0v5 libhdf4-0-alt libilmbase12 libjbig0
#   libjs-jquery libjs-jquery-ui libjson-c3 libkmlbase1 libkmldom1 libkmlengine1
#   liblcms2-2 libleveldb1v5 liblmdb0 libltdl7 liblzo2-2 libminizip1
#   libmysqlclient20 libnetcdf11 libnspr4 libnss3 libodbc1 libogdi3.2
#   libopencv-core3.1 libopencv-imgcodecs3.1 libopencv-imgproc3.1 libopenexr22
#   libopenjp2-7 libpoppler68 libpq5 libproj12 libprotobuf10 libqhull7
#   libsnappy1v5 libspatialite7 libsuperlu5 libtbb2 libtiff5 liburiparser1
#   libwebp6 libwebpmux3 libxerces-c3.1 libxslt1.1 libyaml-0-2 libzstd1
#   mysql-common odbcinst odbcinst1debian2 poppler-data proj-bin proj-data
#   python-matplotlib-data python-pexpect python-ptyprocess python-tables-data
#   python3-bs4 python3-caffe-cuda python3-chardet python3-cycler
#   python3-dateutil python3-decorator python3-gflags python3-h5py
#   python3-html5lib python3-ipython python3-ipython-genutils python3-leveldb
#   python3-lxml python3-matplotlib python3-networkx python3-nose
#   python3-numexpr python3-numpy python3-olefile python3-pandas
#   python3-pandas-lib python3-pexpect python3-pickleshare python3-pil
#   python3-pkg-resources python3-prompt-toolkit python3-protobuf
#   python3-ptyprocess python3-pygments python3-pyparsing python3-pywt
#   python3-scipy python3-simplegeneric python3-six python3-skimage
#   python3-skimage-lib python3-tables python3-tables-lib python3-traitlets
#   python3-tz python3-wcwidth python3-webencodings python3-yaml
#   ttf-bitstream-vera
# Suggested packages:
#   libcaffe-cuda-dev caffe-doc cython-doc apache2 | lighttpd | httpd
#   geotiff-bin gdal-bin libgeotiff-epsg libhdf4-doc libhdf4-alt-dev hdf4-tools
#   libjs-jquery-ui-docs liblcms2-utils libmyodbc odbc-postgresql tdsodbc
#   unixodbc-bin ogdi-bin poppler-utils ghostscript fonts-japanese-mincho
#   | fonts-ipafont-mincho fonts-japanese-gothic | fonts-ipafont-gothic
#   fonts-arphic-ukai fonts-arphic-uming fonts-nanum python-pexpect-doc
#   python-cycler-doc python-h5py-doc python3-genshi python3-lxml-dbg
#   python-lxml-doc dvipng ffmpeg gir1.2-gtk-3.0 inkscape ipython3
#   librsvg2-common python-matplotlib-doc python3-cairocffi python3-gi
#   python3-gi-cairo python3-gobject python3-pyqt4 python3-sip python3-tornado
#   texlive-extra-utils texlive-latex-extra ttf-staypuft python-nose-doc
#   python-numpy-doc python3-numpy-dbg python-pandas-doc python-pil-doc
#   python3-pil-dbg python3-setuptools python-pyparsing-doc python-scipy-doc
#   python-skimage-doc python-tables-doc python-netcdf vitables
# The following NEW packages will be installed:
#   caffe-cuda caffe-tools-cuda cython3 fonts-lyx gdal-data javascript-common
#   libarmadillo7 libarpack2 libblosc1 libboost-python1.62.0
#   libboost-system1.62.0 libboost-thread1.62.0 libcaffe-cuda1 libdap25
#   libdapclient6v5 libepsilon1 libfreexl1 libfyba0 libgdal20 libgeos-3.5.1
#   libgeos-c1v5 libgeotiff2 libgflags2.2 libgif7 libgoogle-glog0v5
#   libhdf4-0-alt libilmbase12 libjbig0 libjs-jquery libjs-jquery-ui libjson-c3
#   libkmlbase1 libkmldom1 libkmlengine1 liblcms2-2 libleveldb1v5 liblmdb0
#   libltdl7 liblzo2-2 libminizip1 libmysqlclient20 libnetcdf11 libnspr4 libnss3
#   libodbc1 libogdi3.2 libopencv-core3.1 libopencv-imgcodecs3.1
#   libopencv-imgproc3.1 libopenexr22 libopenjp2-7 libpoppler68 libpq5 libproj12
#   libprotobuf10 libqhull7 libsnappy1v5 libspatialite7 libsuperlu5 libtbb2
#   libtiff5 liburiparser1 libwebp6 libwebpmux3 libxerces-c3.1 libxslt1.1
#   libyaml-0-2 libzstd1 mysql-common odbcinst odbcinst1debian2 poppler-data
#   proj-bin proj-data python-matplotlib-data python-pexpect python-ptyprocess
#   python-tables-data python3-bs4 python3-caffe-cuda python3-chardet
#   python3-cycler python3-dateutil python3-decorator python3-gflags
#   python3-h5py python3-html5lib python3-ipython python3-ipython-genutils
#   python3-leveldb python3-lxml python3-matplotlib python3-networkx
#   python3-nose python3-numexpr python3-numpy python3-olefile python3-pandas
#   python3-pandas-lib python3-pexpect python3-pickleshare python3-pil
#   python3-pkg-resources python3-prompt-toolkit python3-protobuf
#   python3-ptyprocess python3-pygments python3-pyparsing python3-pywt
#   python3-scipy python3-simplegeneric python3-six python3-skimage
#   python3-skimage-lib python3-tables python3-tables-lib python3-traitlets
#   python3-tz python3-wcwidth python3-webencodings python3-yaml
#   ttf-bitstream-vera
# 0 upgraded, 122 newly installed, 0 to remove and 0 not upgraded.
# Need to get 77.6 MB of archives.
# After this operation, 292 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu artful/main amd64 liblzo2-2 amd64 2.08-1.2 [48.7 kB]
# Get:2 http://archive.ubuntu.com/ubuntu artful/main amd64 poppler-data all 0.4.8-1 [1,476 kB]
# Get:3 http://archive.ubuntu.com/ubuntu artful/main amd64 libjbig0 amd64 2.1-3.1 [26.6 kB]
# Get:4 http://archive.ubuntu.com/ubuntu artful/main amd64 libjson-c3 amd64 0.12.1-1.2 [21.5 kB]
# Get:5 http://archive.ubuntu.com/ubuntu artful/main amd64 libyaml-0-2 amd64 0.1.7-2ubuntu3 [47.2 kB]
# Get:6 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-yaml amd64 3.12-1build2 [109 kB]
# Get:7 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-python1.62.0 amd64 1.62.0+dfsg-4build3 [113 kB]
# Get:8 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-system1.62.0 amd64 1.62.0+dfsg-4build3 [9,212 B]
# Get:9 http://archive.ubuntu.com/ubuntu artful/main amd64 libboost-thread1.62.0 amd64 1.62.0+dfsg-4build3 [47.3 kB]
# Get:10 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgflags2.2 amd64 2.2.1-1 [72.4 kB]
# Get:11 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgoogle-glog0v5 amd64 0.3.5-1 [50.5 kB]
# Get:12 http://archive.ubuntu.com/ubuntu artful/main amd64 libsnappy1v5 amd64 1.1.6-4 [16.0 kB]
# Get:13 http://archive.ubuntu.com/ubuntu artful/main amd64 libleveldb1v5 amd64 1.20-1 [136 kB]
# Get:14 http://archive.ubuntu.com/ubuntu artful/universe amd64 liblmdb0 amd64 0.9.21-1 [43.6 kB]
# Get:15 http://archive.ubuntu.com/ubuntu artful/universe amd64 libtbb2 amd64 2017~U7-6 [112 kB]
# Get:16 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopencv-core3.1 amd64 3.1.0+dfsg1-1~exp1ubuntu3 [698 kB]
# Get:17 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopencv-imgproc3.1 amd64 3.1.0+dfsg1-1~exp1ubuntu3 [778 kB]
# Get:18 http://archive.ubuntu.com/ubuntu artful/universe amd64 gdal-data all 2.2.1+dfsg-2build3 [363 kB]
# Get:19 http://archive.ubuntu.com/ubuntu artful/universe amd64 libarpack2 amd64 3.5.0+real-1 [89.7 kB]
# Get:20 http://archive.ubuntu.com/ubuntu artful/universe amd64 libsuperlu5 amd64 5.2.1+dfsg1-2 [158 kB]
# Get:21 http://archive.ubuntu.com/ubuntu artful/universe amd64 libarmadillo7 amd64 1:7.960.1+dfsg-1 [78.1 kB]
# Get:22 http://archive.ubuntu.com/ubuntu artful/universe amd64 libdap25 amd64 3.19.0-1 [435 kB]
# Get:23 http://archive.ubuntu.com/ubuntu artful/universe amd64 libdapclient6v5 amd64 3.19.0-1 [94.1 kB]
# Get:24 http://archive.ubuntu.com/ubuntu artful/universe amd64 libepsilon1 amd64 0.9.2+dfsg-2 [41.2 kB]
# Get:25 http://archive.ubuntu.com/ubuntu artful/universe amd64 libfreexl1 amd64 1.0.3-1 [33.5 kB]
# Get:26 http://archive.ubuntu.com/ubuntu artful/universe amd64 libfyba0 amd64 4.1.1-3 [110 kB]
# Get:27 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgeos-3.5.1 amd64 3.5.1-3 [474 kB]
# Get:28 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgeos-c1v5 amd64 3.5.1-3 [51.6 kB]
# Get:29 http://archive.ubuntu.com/ubuntu artful/universe amd64 proj-data all 4.9.3-2 [4,020 kB]
# Get:30 http://archive.ubuntu.com/ubuntu artful/universe amd64 libproj12 amd64 4.9.3-2 [159 kB]
# Get:31 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libtiff5 amd64 4.0.8-5ubuntu0.1 [150 kB]
# Get:32 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgeotiff2 amd64 1.4.2-2build1 [58.5 kB]
# Get:33 http://archive.ubuntu.com/ubuntu artful/main amd64 libgif7 amd64 5.1.4-1 [30.7 kB]
# Get:34 http://archive.ubuntu.com/ubuntu artful/universe amd64 libhdf4-0-alt amd64 4.2.13-1 [269 kB]
# Get:35 http://archive.ubuntu.com/ubuntu artful/universe amd64 libminizip1 amd64 1.1-8 [20.3 kB]
# Get:36 http://archive.ubuntu.com/ubuntu artful/universe amd64 liburiparser1 amd64 0.8.4-1 [38.0 kB]
# Get:37 http://archive.ubuntu.com/ubuntu artful/universe amd64 libkmlbase1 amd64 1.3.0-4 [44.4 kB]
# Get:38 http://archive.ubuntu.com/ubuntu artful/universe amd64 libkmldom1 amd64 1.3.0-4 [171 kB]
# Get:39 http://archive.ubuntu.com/ubuntu artful/universe amd64 libkmlengine1 amd64 1.3.0-4 [73.8 kB]
# Get:40 http://archive.ubuntu.com/ubuntu artful/main amd64 mysql-common all 5.8+1.0.2ubuntu1 [5,782 B]
# Get:41 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libmysqlclient20 amd64 5.7.22-0ubuntu0.17.10.1 [815 kB]
# Get:42 http://archive.ubuntu.com/ubuntu artful/universe amd64 libnetcdf11 amd64 1:4.4.1.1-2ubuntu1 [292 kB]
# Get:43 http://archive.ubuntu.com/ubuntu artful/main amd64 libltdl7 amd64 2.4.6-2 [38.8 kB]
# Get:44 http://archive.ubuntu.com/ubuntu artful/main amd64 libodbc1 amd64 2.3.4-1 [183 kB]
# Get:45 http://archive.ubuntu.com/ubuntu artful/universe amd64 libogdi3.2 amd64 3.2.0+ds-2 [213 kB]
# Get:46 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopenjp2-7 amd64 2.2.0-1 [133 kB]
# Get:47 http://archive.ubuntu.com/ubuntu artful/main amd64 liblcms2-2 amd64 2.7-1ubuntu1 [137 kB]
# Get:48 http://archive.ubuntu.com/ubuntu artful/main amd64 libnspr4 amd64 2:4.16-1ubuntu2 [112 kB]
# Get:49 http://archive.ubuntu.com/ubuntu artful/main amd64 libnss3 amd64 2:3.32-1ubuntu3 [1,141 kB]
# Get:50 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpoppler68 amd64 0.57.0-2ubuntu4.3 [787 kB]
# Get:51 http://archive.ubuntu.com/ubuntu artful-updates/main amd64 libpq5 amd64 9.6.9-0ubuntu0.17.10 [81.0 kB]
# Get:52 http://archive.ubuntu.com/ubuntu artful/universe amd64 libqhull7 amd64 2015.2-2 [151 kB]
# Get:53 http://archive.ubuntu.com/ubuntu artful/universe amd64 libspatialite7 amd64 4.3.0a-5build1 [1,224 kB]
# Get:54 http://archive.ubuntu.com/ubuntu artful/main amd64 libwebp6 amd64 0.6.0-3 [181 kB]
# Get:55 http://archive.ubuntu.com/ubuntu artful/universe amd64 libxerces-c3.1 amd64 3.1.4+debian-2 [839 kB]
# Get:56 http://archive.ubuntu.com/ubuntu artful/main amd64 odbcinst amd64 2.3.4-1 [12.8 kB]
# Get:57 http://archive.ubuntu.com/ubuntu artful/main amd64 odbcinst1debian2 amd64 2.3.4-1 [41.2 kB]
# Get:58 http://archive.ubuntu.com/ubuntu artful/universe amd64 libgdal20 amd64 2.2.1+dfsg-2build3 [5,100 kB]
# Get:59 http://archive.ubuntu.com/ubuntu artful/main amd64 libilmbase12 amd64 2.2.0-11ubuntu2 [71.4 kB]
# Get:60 http://archive.ubuntu.com/ubuntu artful/main amd64 libopenexr22 amd64 2.2.0-11ubuntu1 [552 kB]
# Get:61 http://archive.ubuntu.com/ubuntu artful/universe amd64 libopencv-imgcodecs3.1 amd64 3.1.0+dfsg1-1~exp1ubuntu3 [70.9 kB]
# Get:62 http://archive.ubuntu.com/ubuntu artful/main amd64 libprotobuf10 amd64 3.0.0-9ubuntu5 [650 kB]
# Get:63 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 libcaffe-cuda1 amd64 1.0.0-3build1 [1,510 kB]
# Get:64 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 caffe-tools-cuda amd64 1.0.0-3build1 [88.2 kB]
# Get:65 http://archive.ubuntu.com/ubuntu artful/universe amd64 cython3 amd64 0.25.2-2build3 [1,823 kB]
# Get:66 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-six all 1.10.0-4 [10.8 kB]
# Get:67 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-dateutil all 2.6.0-1 [51.5 kB]
# Get:68 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-gflags all 1.5.1-3 [35.4 kB]
# Get:69 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-numpy amd64 1:1.12.1-3.1ubuntu4 [1,893 kB]
# Get:70 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-h5py amd64 2.7.1-2 [631 kB]
# Get:71 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-decorator all 4.1.1-1 [9,264 B]
# Get:72 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-ptyprocess all 0.5.2-1 [12.7 kB]
# Get:73 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-pexpect all 4.2.1-1 [42.4 kB]
# Get:74 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-pickleshare all 0.7.4-2 [6,904 B]
# Get:75 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-pkg-resources all 36.2.7-2 [98.7 kB]
# Get:76 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-wcwidth all 0.1.7+dfsg1-1 [14.7 kB]
# Get:77 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-prompt-toolkit all 1.0.14-1 [163 kB]
# Get:78 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-pygments all 2.2.0+dfsg-1 [574 kB]
# Get:79 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-simplegeneric all 0.8.1-1 [11.5 kB]
# Get:80 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-ipython-genutils all 0.2.0-1 [20.9 kB]
# Get:81 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-traitlets all 4.3.2-1 [59.1 kB]
# Get:82 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-ptyprocess all 0.5.2-1 [12.6 kB]
# Get:83 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-pexpect all 4.2.1-1 [41.7 kB]
# Get:84 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-ipython all 5.1.0-3 [375 kB]
# Get:85 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-leveldb amd64 0~svn68-3build3 [18.3 kB]
# Get:86 http://archive.ubuntu.com/ubuntu artful/universe amd64 fonts-lyx all 2.2.3-1 [155 kB]
# Get:87 http://archive.ubuntu.com/ubuntu artful/universe amd64 ttf-bitstream-vera all 1.10-8 [352 kB]
# Get:88 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-matplotlib-data all 2.0.0+dfsg1-2ubuntu3 [3,990 kB]
# Get:89 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-pyparsing all 2.1.10+dfsg1-1 [51.8 kB]
# Get:90 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-tz all 2017.2-2 [25.1 kB]
# Get:91 http://archive.ubuntu.com/ubuntu artful/main amd64 libjs-jquery all 3.1.1-2 [151 kB]
# Get:92 http://archive.ubuntu.com/ubuntu artful/universe amd64 libjs-jquery-ui all 1.12.1+dfsg-5 [232 kB]
# Get:93 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-cycler all 0.10.0-1 [7,622 B]
# Get:94 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-matplotlib amd64 2.0.0+dfsg1-2ubuntu3 [1,491 kB]
# Get:95 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-networkx all 1.11-1ubuntu1 [608 kB]
# Get:96 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-nose all 1.3.7-2 [116 kB]
# Get:97 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-pandas-lib amd64 0.19.2-5.1ubuntu4 [2,156 kB]
# Get:98 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-pandas all 0.19.2-5.1ubuntu4 [2,605 kB]
# Get:99 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-olefile all 0.44-1 [36.3 kB]
# Get:100 http://archive.ubuntu.com/ubuntu artful/main amd64 libwebpmux3 amd64 0.6.0-3 [20.0 kB]
# Get:101 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-pil amd64 4.1.1-3build2 [312 kB]
# Get:102 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-protobuf amd64 3.0.0-9ubuntu5 [263 kB]
# Get:103 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-scipy amd64 0.18.1-2ubuntu5 [8,519 kB]
# Get:104 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-skimage-lib amd64 0.13.0-0ubuntu4 [1,503 kB]
# Get:105 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-pywt amd64 0.5.1-1.1ubuntu4 [932 kB]
# Get:106 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-skimage all 0.13.0-0ubuntu4 [19.6 MB]
# Get:107 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 python3-caffe-cuda amd64 1.0.0-3build1 [681 kB]
# Get:108 http://archive.ubuntu.com/ubuntu artful/multiverse amd64 caffe-cuda amd64 1.0.0-3build1 [4,480 B]
# Get:109 http://archive.ubuntu.com/ubuntu artful/main amd64 javascript-common all 11 [6,066 B]
# Get:110 http://archive.ubuntu.com/ubuntu artful-updates/universe amd64 libzstd1 amd64 1.3.1+dfsg-1ubuntu0.1 [152 kB]
# Get:111 http://archive.ubuntu.com/ubuntu artful/universe amd64 libblosc1 amd64 1.11.1+ds2-2 [31.7 kB]
# Get:112 http://archive.ubuntu.com/ubuntu artful/main amd64 libxslt1.1 amd64 1.1.29-2.1ubuntu1 [149 kB]
# Get:113 http://archive.ubuntu.com/ubuntu artful/universe amd64 python-tables-data all 3.3.0-5build4 [45.2 kB]
# Get:114 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-bs4 all 4.6.0-1 [67.8 kB]
# Get:115 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-chardet all 3.0.4-1 [80.3 kB]
# Get:116 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-webencodings all 0.5-2 [10.4 kB]
# Get:117 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-html5lib all 0.999999999-1 [81.9 kB]
# Get:118 http://archive.ubuntu.com/ubuntu artful/main amd64 python3-lxml amd64 4.0.0-1 [1,135 kB]
# Get:119 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-numexpr amd64 2.6.2-2 [119 kB]
# Get:120 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-tables-lib amd64 3.3.0-5build4 [390 kB]
# Get:121 http://archive.ubuntu.com/ubuntu artful/universe amd64 python3-tables all 3.3.0-5build4 [324 kB]
# Get:122 http://archive.ubuntu.com/ubuntu artful/universe amd64 proj-bin amd64 4.9.3-2 [32.3 kB]
# Fetched 77.6 MB in 10s (7,702 kB/s)
# Extracting templates from packages: 100%
#
# 78Selecting previously unselected package liblzo2-2:amd64.
# (Reading database ... 18408 files and directories currently installed.)
# Preparing to unpack .../000-liblzo2-2_2.08-1.2_amd64.deb ...
# 7Progress: [  0%] [..........................................................] 8Unpacking liblzo2-2:amd64 (2.08-1.2) ...
# Selecting previously unselected package poppler-data.
# Preparing to unpack .../001-poppler-data_0.4.8-1_all.deb ...
# Unpacking poppler-data (0.4.8-1) ...
# Selecting previously unselected package libjbig0:amd64.
# Preparing to unpack .../002-libjbig0_2.1-3.1_amd64.deb ...
# 7Progress: [  1%] [..........................................................] 8Unpacking libjbig0:amd64 (2.1-3.1) ...
# Selecting previously unselected package libjson-c3:amd64.
# Preparing to unpack .../003-libjson-c3_0.12.1-1.2_amd64.deb ...
# Unpacking libjson-c3:amd64 (0.12.1-1.2) ...
# Selecting previously unselected package libyaml-0-2:amd64.
# Preparing to unpack .../004-libyaml-0-2_0.1.7-2ubuntu3_amd64.deb ...
# 7Progress: [  2%] [#.........................................................] 8Unpacking libyaml-0-2:amd64 (0.1.7-2ubuntu3) ...
# Selecting previously unselected package python3-yaml.
# Preparing to unpack .../005-python3-yaml_3.12-1build2_amd64.deb ...
# Unpacking python3-yaml (3.12-1build2) ...
# Selecting previously unselected package libboost-python1.62.0.
# Preparing to unpack .../006-libboost-python1.62.0_1.62.0+dfsg-4build3_amd64.deb ...
# 7Progress: [  3%] [#.........................................................] 8Unpacking libboost-python1.62.0 (1.62.0+dfsg-4build3) ...
# Selecting previously unselected package libboost-system1.62.0:amd64.
# Preparing to unpack .../007-libboost-system1.62.0_1.62.0+dfsg-4build3_amd64.deb ...
# Unpacking libboost-system1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Selecting previously unselected package libboost-thread1.62.0:amd64.
# Preparing to unpack .../008-libboost-thread1.62.0_1.62.0+dfsg-4build3_amd64.deb ...
# 7Progress: [  4%] [##........................................................] 8Unpacking libboost-thread1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# Selecting previously unselected package libgflags2.2.
# Preparing to unpack .../009-libgflags2.2_2.2.1-1_amd64.deb ...
# Unpacking libgflags2.2 (2.2.1-1) ...
# Selecting previously unselected package libgoogle-glog0v5.
# Preparing to unpack .../010-libgoogle-glog0v5_0.3.5-1_amd64.deb ...
# 7Progress: [  5%] [##........................................................] 8Unpacking libgoogle-glog0v5 (0.3.5-1) ...
# Selecting previously unselected package libsnappy1v5:amd64.
# Preparing to unpack .../011-libsnappy1v5_1.1.6-4_amd64.deb ...
# Unpacking libsnappy1v5:amd64 (1.1.6-4) ...
# Selecting previously unselected package libleveldb1v5:amd64.
# Preparing to unpack .../012-libleveldb1v5_1.20-1_amd64.deb ...
# 7Progress: [  6%] [###.......................................................] 8Unpacking libleveldb1v5:amd64 (1.20-1) ...
# Selecting previously unselected package liblmdb0:amd64.
# Preparing to unpack .../013-liblmdb0_0.9.21-1_amd64.deb ...
# Unpacking liblmdb0:amd64 (0.9.21-1) ...
# Selecting previously unselected package libtbb2:amd64.
# Preparing to unpack .../014-libtbb2_2017~U7-6_amd64.deb ...
# 7Progress: [  7%] [####......................................................] 8Unpacking libtbb2:amd64 (2017~U7-6) ...
# Selecting previously unselected package libopencv-core3.1:amd64.
# Preparing to unpack .../015-libopencv-core3.1_3.1.0+dfsg1-1~exp1ubuntu3_amd64.deb ...
# Unpacking libopencv-core3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Selecting previously unselected package libopencv-imgproc3.1:amd64.
# Preparing to unpack .../016-libopencv-imgproc3.1_3.1.0+dfsg1-1~exp1ubuntu3_amd64.deb ...
# 7Progress: [  8%] [####......................................................] 8Unpacking libopencv-imgproc3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Selecting previously unselected package gdal-data.
# Preparing to unpack .../017-gdal-data_2.2.1+dfsg-2build3_all.deb ...
# Unpacking gdal-data (2.2.1+dfsg-2build3) ...
# Selecting previously unselected package libarpack2:amd64.
# Preparing to unpack .../018-libarpack2_3.5.0+real-1_amd64.deb ...
# 7Progress: [  9%] [#####.....................................................] 8Unpacking libarpack2:amd64 (3.5.0+real-1) ...
# Selecting previously unselected package libsuperlu5:amd64.
# Preparing to unpack .../019-libsuperlu5_5.2.1+dfsg1-2_amd64.deb ...
# Unpacking libsuperlu5:amd64 (5.2.1+dfsg1-2) ...
# Selecting previously unselected package libarmadillo7.
# Preparing to unpack .../020-libarmadillo7_1%3a7.960.1+dfsg-1_amd64.deb ...
# Unpacking libarmadillo7 (1:7.960.1+dfsg-1) ...
# 7Progress: [ 10%] [#####.....................................................] 8Selecting previously unselected package libdap25:amd64.
# Preparing to unpack .../021-libdap25_3.19.0-1_amd64.deb ...
# Unpacking libdap25:amd64 (3.19.0-1) ...
# Selecting previously unselected package libdapclient6v5:amd64.
# Preparing to unpack .../022-libdapclient6v5_3.19.0-1_amd64.deb ...
# Unpacking libdapclient6v5:amd64 (3.19.0-1) ...
# 7Progress: [ 11%] [######....................................................] 8Selecting previously unselected package libepsilon1:amd64.
# Preparing to unpack .../023-libepsilon1_0.9.2+dfsg-2_amd64.deb ...
# Unpacking libepsilon1:amd64 (0.9.2+dfsg-2) ...
# Selecting previously unselected package libfreexl1:amd64.
# Preparing to unpack .../024-libfreexl1_1.0.3-1_amd64.deb ...
# Unpacking libfreexl1:amd64 (1.0.3-1) ...
# 7Progress: [ 12%] [#######...................................................] 8Selecting previously unselected package libfyba0:amd64.
# Preparing to unpack .../025-libfyba0_4.1.1-3_amd64.deb ...
# Unpacking libfyba0:amd64 (4.1.1-3) ...
# Selecting previously unselected package libgeos-3.5.1.
# Preparing to unpack .../026-libgeos-3.5.1_3.5.1-3_amd64.deb ...
# Unpacking libgeos-3.5.1 (3.5.1-3) ...
# 7Progress: [ 13%] [#######...................................................] 8Selecting previously unselected package libgeos-c1v5.
# Preparing to unpack .../027-libgeos-c1v5_3.5.1-3_amd64.deb ...
# Unpacking libgeos-c1v5 (3.5.1-3) ...
# Selecting previously unselected package proj-data.
# Preparing to unpack .../028-proj-data_4.9.3-2_all.deb ...
# Unpacking proj-data (4.9.3-2) ...
# 7Progress: [ 14%] [########..................................................] 8Selecting previously unselected package libproj12:amd64.
# Preparing to unpack .../029-libproj12_4.9.3-2_amd64.deb ...
# Unpacking libproj12:amd64 (4.9.3-2) ...
# Selecting previously unselected package libtiff5:amd64.
# Preparing to unpack .../030-libtiff5_4.0.8-5ubuntu0.1_amd64.deb ...
# Unpacking libtiff5:amd64 (4.0.8-5ubuntu0.1) ...
# 7Progress: [ 15%] [########..................................................] 8Selecting previously unselected package libgeotiff2:amd64.
# Preparing to unpack .../031-libgeotiff2_1.4.2-2build1_amd64.deb ...
# Unpacking libgeotiff2:amd64 (1.4.2-2build1) ...
# Selecting previously unselected package libgif7:amd64.
# Preparing to unpack .../032-libgif7_5.1.4-1_amd64.deb ...
# Unpacking libgif7:amd64 (5.1.4-1) ...
# 7Progress: [ 16%] [#########.................................................] 8Selecting previously unselected package libhdf4-0-alt.
# Preparing to unpack .../033-libhdf4-0-alt_4.2.13-1_amd64.deb ...
# Unpacking libhdf4-0-alt (4.2.13-1) ...
# Selecting previously unselected package libminizip1:amd64.
# Preparing to unpack .../034-libminizip1_1.1-8_amd64.deb ...
# Unpacking libminizip1:amd64 (1.1-8) ...
# 7Progress: [ 17%] [#########.................................................] 8Selecting previously unselected package liburiparser1:amd64.
# Preparing to unpack .../035-liburiparser1_0.8.4-1_amd64.deb ...
# Unpacking liburiparser1:amd64 (0.8.4-1) ...
# Selecting previously unselected package libkmlbase1:amd64.
# Preparing to unpack .../036-libkmlbase1_1.3.0-4_amd64.deb ...
# Unpacking libkmlbase1:amd64 (1.3.0-4) ...
# 7Progress: [ 18%] [##########................................................] 8Selecting previously unselected package libkmldom1:amd64.
# Preparing to unpack .../037-libkmldom1_1.3.0-4_amd64.deb ...
# Unpacking libkmldom1:amd64 (1.3.0-4) ...
# Selecting previously unselected package libkmlengine1:amd64.
# Preparing to unpack .../038-libkmlengine1_1.3.0-4_amd64.deb ...
# Unpacking libkmlengine1:amd64 (1.3.0-4) ...
# 7Progress: [ 19%] [###########...............................................] 8Selecting previously unselected package mysql-common.
# Preparing to unpack .../039-mysql-common_5.8+1.0.2ubuntu1_all.deb ...
# Unpacking mysql-common (5.8+1.0.2ubuntu1) ...
# Selecting previously unselected package libmysqlclient20:amd64.
# Preparing to unpack .../040-libmysqlclient20_5.7.22-0ubuntu0.17.10.1_amd64.deb ...
# Unpacking libmysqlclient20:amd64 (5.7.22-0ubuntu0.17.10.1) ...
# 7Progress: [ 20%] [###########...............................................] 8Selecting previously unselected package libnetcdf11.
# Preparing to unpack .../041-libnetcdf11_1%3a4.4.1.1-2ubuntu1_amd64.deb ...
# Unpacking libnetcdf11 (1:4.4.1.1-2ubuntu1) ...
# Selecting previously unselected package libltdl7:amd64.
# Preparing to unpack .../042-libltdl7_2.4.6-2_amd64.deb ...
# Unpacking libltdl7:amd64 (2.4.6-2) ...
# 7Progress: [ 21%] [############..............................................] 8Selecting previously unselected package libodbc1:amd64.
# Preparing to unpack .../043-libodbc1_2.3.4-1_amd64.deb ...
# Unpacking libodbc1:amd64 (2.3.4-1) ...
# Selecting previously unselected package libogdi3.2.
# Preparing to unpack .../044-libogdi3.2_3.2.0+ds-2_amd64.deb ...
# Unpacking libogdi3.2 (3.2.0+ds-2) ...
# 7Progress: [ 22%] [############..............................................] 8Selecting previously unselected package libopenjp2-7:amd64.
# Preparing to unpack .../045-libopenjp2-7_2.2.0-1_amd64.deb ...
# Unpacking libopenjp2-7:amd64 (2.2.0-1) ...
# Selecting previously unselected package liblcms2-2:amd64.
# Preparing to unpack .../046-liblcms2-2_2.7-1ubuntu1_amd64.deb ...
# Unpacking liblcms2-2:amd64 (2.7-1ubuntu1) ...
# 7Progress: [ 23%] [#############.............................................] 8Selecting previously unselected package libnspr4:amd64.
# Preparing to unpack .../047-libnspr4_2%3a4.16-1ubuntu2_amd64.deb ...
# Unpacking libnspr4:amd64 (2:4.16-1ubuntu2) ...
# Selecting previously unselected package libnss3:amd64.
# Preparing to unpack .../048-libnss3_2%3a3.32-1ubuntu3_amd64.deb ...
# Unpacking libnss3:amd64 (2:3.32-1ubuntu3) ...
# 7Progress: [ 24%] [#############.............................................] 8Selecting previously unselected package libpoppler68:amd64.
# Preparing to unpack .../049-libpoppler68_0.57.0-2ubuntu4.3_amd64.deb ...
# Unpacking libpoppler68:amd64 (0.57.0-2ubuntu4.3) ...
# Selecting previously unselected package libpq5:amd64.
# Preparing to unpack .../050-libpq5_9.6.9-0ubuntu0.17.10_amd64.deb ...
# Unpacking libpq5:amd64 (9.6.9-0ubuntu0.17.10) ...
# 7Progress: [ 25%] [##############............................................] 8Selecting previously unselected package libqhull7:amd64.
# Preparing to unpack .../051-libqhull7_2015.2-2_amd64.deb ...
# Unpacking libqhull7:amd64 (2015.2-2) ...
# Selecting previously unselected package libspatialite7:amd64.
# Preparing to unpack .../052-libspatialite7_4.3.0a-5build1_amd64.deb ...
# Unpacking libspatialite7:amd64 (4.3.0a-5build1) ...
# 7Progress: [ 26%] [###############...........................................] 8Selecting previously unselected package libwebp6:amd64.
# Preparing to unpack .../053-libwebp6_0.6.0-3_amd64.deb ...
# Unpacking libwebp6:amd64 (0.6.0-3) ...
# Selecting previously unselected package libxerces-c3.1:amd64.
# Preparing to unpack .../054-libxerces-c3.1_3.1.4+debian-2_amd64.deb ...
# Unpacking libxerces-c3.1:amd64 (3.1.4+debian-2) ...
# 7Progress: [ 27%] [###############...........................................] 8Selecting previously unselected package odbcinst.
# Preparing to unpack .../055-odbcinst_2.3.4-1_amd64.deb ...
# Unpacking odbcinst (2.3.4-1) ...
# Selecting previously unselected package odbcinst1debian2:amd64.
# Preparing to unpack .../056-odbcinst1debian2_2.3.4-1_amd64.deb ...
# Unpacking odbcinst1debian2:amd64 (2.3.4-1) ...
# Selecting previously unselected package libgdal20.
# Preparing to unpack .../057-libgdal20_2.2.1+dfsg-2build3_amd64.deb ...
# 7Progress: [ 28%] [################..........................................] 8Unpacking libgdal20 (2.2.1+dfsg-2build3) ...
# Selecting previously unselected package libilmbase12:amd64.
# Preparing to unpack .../058-libilmbase12_2.2.0-11ubuntu2_amd64.deb ...
# Unpacking libilmbase12:amd64 (2.2.0-11ubuntu2) ...
# Selecting previously unselected package libopenexr22:amd64.
# Preparing to unpack .../059-libopenexr22_2.2.0-11ubuntu1_amd64.deb ...
# 7Progress: [ 29%] [################..........................................] 8Unpacking libopenexr22:amd64 (2.2.0-11ubuntu1) ...
# Selecting previously unselected package libopencv-imgcodecs3.1:amd64.
# Preparing to unpack .../060-libopencv-imgcodecs3.1_3.1.0+dfsg1-1~exp1ubuntu3_amd64.deb ...
# Unpacking libopencv-imgcodecs3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Selecting previously unselected package libprotobuf10:amd64.
# Preparing to unpack .../061-libprotobuf10_3.0.0-9ubuntu5_amd64.deb ...
# 7Progress: [ 30%] [#################.........................................] 8Unpacking libprotobuf10:amd64 (3.0.0-9ubuntu5) ...
# Selecting previously unselected package libcaffe-cuda1:amd64.
# Preparing to unpack .../062-libcaffe-cuda1_1.0.0-3build1_amd64.deb ...
# Unpacking libcaffe-cuda1:amd64 (1.0.0-3build1) ...
# Selecting previously unselected package caffe-tools-cuda.
# Preparing to unpack .../063-caffe-tools-cuda_1.0.0-3build1_amd64.deb ...
# 7Progress: [ 31%] [##################........................................] 8Unpacking caffe-tools-cuda (1.0.0-3build1) ...
# Selecting previously unselected package cython3.
# Preparing to unpack .../064-cython3_0.25.2-2build3_amd64.deb ...
# Unpacking cython3 (0.25.2-2build3) ...
# Selecting previously unselected package python3-six.
# Preparing to unpack .../065-python3-six_1.10.0-4_all.deb ...
# 7Progress: [ 32%] [##################........................................] 8Unpacking python3-six (1.10.0-4) ...
# Selecting previously unselected package python3-dateutil.
# Preparing to unpack .../066-python3-dateutil_2.6.0-1_all.deb ...
# Unpacking python3-dateutil (2.6.0-1) ...
# Selecting previously unselected package python3-gflags.
# Preparing to unpack .../067-python3-gflags_1.5.1-3_all.deb ...
# 7Progress: [ 33%] [###################.......................................] 8Unpacking python3-gflags (1.5.1-3) ...
# Selecting previously unselected package python3-numpy.
# Preparing to unpack .../068-python3-numpy_1%3a1.12.1-3.1ubuntu4_amd64.deb ...
# Unpacking python3-numpy (1:1.12.1-3.1ubuntu4) ...
# Selecting previously unselected package python3-h5py.
# Preparing to unpack .../069-python3-h5py_2.7.1-2_amd64.deb ...
# 7Progress: [ 34%] [###################.......................................] 8Unpacking python3-h5py (2.7.1-2) ...
# Selecting previously unselected package python3-decorator.
# Preparing to unpack .../070-python3-decorator_4.1.1-1_all.deb ...
# Unpacking python3-decorator (4.1.1-1) ...
# Selecting previously unselected package python3-ptyprocess.
# Preparing to unpack .../071-python3-ptyprocess_0.5.2-1_all.deb ...
# 7Progress: [ 35%] [####################......................................] 8Unpacking python3-ptyprocess (0.5.2-1) ...
# Selecting previously unselected package python3-pexpect.
# Preparing to unpack .../072-python3-pexpect_4.2.1-1_all.deb ...
# Unpacking python3-pexpect (4.2.1-1) ...
# Selecting previously unselected package python3-pickleshare.
# Preparing to unpack .../073-python3-pickleshare_0.7.4-2_all.deb ...
# 7Progress: [ 36%] [####################......................................] 8Unpacking python3-pickleshare (0.7.4-2) ...
# Selecting previously unselected package python3-pkg-resources.
# Preparing to unpack .../074-python3-pkg-resources_36.2.7-2_all.deb ...
# Unpacking python3-pkg-resources (36.2.7-2) ...
# Selecting previously unselected package python3-wcwidth.
# Preparing to unpack .../075-python3-wcwidth_0.1.7+dfsg1-1_all.deb ...
# Unpacking python3-wcwidth (0.1.7+dfsg1-1) ...
# 7Progress: [ 37%] [#####################.....................................] 8Selecting previously unselected package python3-prompt-toolkit.
# Preparing to unpack .../076-python3-prompt-toolkit_1.0.14-1_all.deb ...
# Unpacking python3-prompt-toolkit (1.0.14-1) ...
# Selecting previously unselected package python3-pygments.
# Preparing to unpack .../077-python3-pygments_2.2.0+dfsg-1_all.deb ...
# Unpacking python3-pygments (2.2.0+dfsg-1) ...
# 7Progress: [ 38%] [######################....................................] 8Selecting previously unselected package python3-simplegeneric.
# Preparing to unpack .../078-python3-simplegeneric_0.8.1-1_all.deb ...
# Unpacking python3-simplegeneric (0.8.1-1) ...
# Selecting previously unselected package python3-ipython-genutils.
# Preparing to unpack .../079-python3-ipython-genutils_0.2.0-1_all.deb ...
# Unpacking python3-ipython-genutils (0.2.0-1) ...
# 7Progress: [ 39%] [######################....................................] 8Selecting previously unselected package python3-traitlets.
# Preparing to unpack .../080-python3-traitlets_4.3.2-1_all.deb ...
# Unpacking python3-traitlets (4.3.2-1) ...
# Selecting previously unselected package python-ptyprocess.
# Preparing to unpack .../081-python-ptyprocess_0.5.2-1_all.deb ...
# Unpacking python-ptyprocess (0.5.2-1) ...
# 7Progress: [ 40%] [#######################...................................] 8Selecting previously unselected package python-pexpect.
# Preparing to unpack .../082-python-pexpect_4.2.1-1_all.deb ...
# Unpacking python-pexpect (4.2.1-1) ...
# Selecting previously unselected package python3-ipython.
# Preparing to unpack .../083-python3-ipython_5.1.0-3_all.deb ...
# Unpacking python3-ipython (5.1.0-3) ...
# 7Progress: [ 41%] [#######################...................................] 8Selecting previously unselected package python3-leveldb.
# Preparing to unpack .../084-python3-leveldb_0~svn68-3build3_amd64.deb ...
# Unpacking python3-leveldb (0~svn68-3build3) ...
# Selecting previously unselected package fonts-lyx.
# Preparing to unpack .../085-fonts-lyx_2.2.3-1_all.deb ...
# Unpacking fonts-lyx (2.2.3-1) ...
# 7Progress: [ 42%] [########################..................................] 8Selecting previously unselected package ttf-bitstream-vera.
# Preparing to unpack .../086-ttf-bitstream-vera_1.10-8_all.deb ...
# Unpacking ttf-bitstream-vera (1.10-8) ...
# Selecting previously unselected package python-matplotlib-data.
# Preparing to unpack .../087-python-matplotlib-data_2.0.0+dfsg1-2ubuntu3_all.deb ...
# Unpacking python-matplotlib-data (2.0.0+dfsg1-2ubuntu3) ...
# 7Progress: [ 43%] [########################..................................] 8Selecting previously unselected package python3-pyparsing.
# Preparing to unpack .../088-python3-pyparsing_2.1.10+dfsg1-1_all.deb ...
# Unpacking python3-pyparsing (2.1.10+dfsg1-1) ...
# Selecting previously unselected package python3-tz.
# Preparing to unpack .../089-python3-tz_2017.2-2_all.deb ...
# Unpacking python3-tz (2017.2-2) ...
# 7Progress: [ 44%] [#########################.................................] 8Selecting previously unselected package libjs-jquery.
# Preparing to unpack .../090-libjs-jquery_3.1.1-2_all.deb ...
# Unpacking libjs-jquery (3.1.1-2) ...
# Selecting previously unselected package libjs-jquery-ui.
# Preparing to unpack .../091-libjs-jquery-ui_1.12.1+dfsg-5_all.deb ...
# Unpacking libjs-jquery-ui (1.12.1+dfsg-5) ...
# 7Progress: [ 45%] [##########################................................] 8Selecting previously unselected package python3-cycler.
# Preparing to unpack .../092-python3-cycler_0.10.0-1_all.deb ...
# Unpacking python3-cycler (0.10.0-1) ...
# Selecting previously unselected package python3-matplotlib.
# Preparing to unpack .../093-python3-matplotlib_2.0.0+dfsg1-2ubuntu3_amd64.deb ...
# Unpacking python3-matplotlib (2.0.0+dfsg1-2ubuntu3) ...
# 7Progress: [ 46%] [##########################................................] 8Selecting previously unselected package python3-networkx.
# Preparing to unpack .../094-python3-networkx_1.11-1ubuntu1_all.deb ...
# Unpacking python3-networkx (1.11-1ubuntu1) ...
# Selecting previously unselected package python3-nose.
# Preparing to unpack .../095-python3-nose_1.3.7-2_all.deb ...
# Unpacking python3-nose (1.3.7-2) ...
# 7Progress: [ 47%] [###########################...............................] 8Selecting previously unselected package python3-pandas-lib.
# Preparing to unpack .../096-python3-pandas-lib_0.19.2-5.1ubuntu4_amd64.deb ...
# Unpacking python3-pandas-lib (0.19.2-5.1ubuntu4) ...
# Selecting previously unselected package python3-pandas.
# Preparing to unpack .../097-python3-pandas_0.19.2-5.1ubuntu4_all.deb ...
# Unpacking python3-pandas (0.19.2-5.1ubuntu4) ...
# 7Progress: [ 48%] [###########################...............................] 8Selecting previously unselected package python3-olefile.
# Preparing to unpack .../098-python3-olefile_0.44-1_all.deb ...
# Unpacking python3-olefile (0.44-1) ...
# Selecting previously unselected package libwebpmux3:amd64.
# Preparing to unpack .../099-libwebpmux3_0.6.0-3_amd64.deb ...
# Unpacking libwebpmux3:amd64 (0.6.0-3) ...
# 7Progress: [ 49%] [############################..............................] 8Selecting previously unselected package python3-pil:amd64.
# Preparing to unpack .../100-python3-pil_4.1.1-3build2_amd64.deb ...
# Unpacking python3-pil:amd64 (4.1.1-3build2) ...
# Selecting previously unselected package python3-protobuf.
# Preparing to unpack .../101-python3-protobuf_3.0.0-9ubuntu5_amd64.deb ...
# Unpacking python3-protobuf (3.0.0-9ubuntu5) ...
# 7Progress: [ 50%] [#############################.............................] 8Selecting previously unselected package python3-scipy.
# Preparing to unpack .../102-python3-scipy_0.18.1-2ubuntu5_amd64.deb ...
# Unpacking python3-scipy (0.18.1-2ubuntu5) ...
# Selecting previously unselected package python3-skimage-lib:amd64.
# Preparing to unpack .../103-python3-skimage-lib_0.13.0-0ubuntu4_amd64.deb ...
# Unpacking python3-skimage-lib:amd64 (0.13.0-0ubuntu4) ...
# 7Progress: [ 51%] [#############################.............................] 8Selecting previously unselected package python3-pywt.
# Preparing to unpack .../104-python3-pywt_0.5.1-1.1ubuntu4_amd64.deb ...
# Unpacking python3-pywt (0.5.1-1.1ubuntu4) ...
# Selecting previously unselected package python3-skimage.
# Preparing to unpack .../105-python3-skimage_0.13.0-0ubuntu4_all.deb ...
# Unpacking python3-skimage (0.13.0-0ubuntu4) ...
# 7Progress: [ 52%] [##############################............................] 8Selecting previously unselected package python3-caffe-cuda.
# Preparing to unpack .../106-python3-caffe-cuda_1.0.0-3build1_amd64.deb ...
# Unpacking python3-caffe-cuda (1.0.0-3build1) ...
# Selecting previously unselected package caffe-cuda.
# Preparing to unpack .../107-caffe-cuda_1.0.0-3build1_amd64.deb ...
# Unpacking caffe-cuda (1.0.0-3build1) ...
# 7Progress: [ 53%] [##############################............................] 8Selecting previously unselected package javascript-common.
# Preparing to unpack .../108-javascript-common_11_all.deb ...
# Unpacking javascript-common (11) ...
# Selecting previously unselected package libzstd1.
# Preparing to unpack .../109-libzstd1_1.3.1+dfsg-1ubuntu0.1_amd64.deb ...
# Unpacking libzstd1 (1.3.1+dfsg-1ubuntu0.1) ...
# 7Progress: [ 54%] [###############################...........................] 8Selecting previously unselected package libblosc1.
# Preparing to unpack .../110-libblosc1_1.11.1+ds2-2_amd64.deb ...
# Unpacking libblosc1 (1.11.1+ds2-2) ...
# Selecting previously unselected package libxslt1.1:amd64.
# Preparing to unpack .../111-libxslt1.1_1.1.29-2.1ubuntu1_amd64.deb ...
# Unpacking libxslt1.1:amd64 (1.1.29-2.1ubuntu1) ...
# Selecting previously unselected package python-tables-data.
# Preparing to unpack .../112-python-tables-data_3.3.0-5build4_all.deb ...
# 7Progress: [ 55%] [###############################...........................] 8Unpacking python-tables-data (3.3.0-5build4) ...
# Selecting previously unselected package python3-bs4.
# Preparing to unpack .../113-python3-bs4_4.6.0-1_all.deb ...
# Unpacking python3-bs4 (4.6.0-1) ...
# Selecting previously unselected package python3-chardet.
# Preparing to unpack .../114-python3-chardet_3.0.4-1_all.deb ...
# 7Progress: [ 56%] [################################..........................] 8Unpacking python3-chardet (3.0.4-1) ...
# Selecting previously unselected package python3-webencodings.
# Preparing to unpack .../115-python3-webencodings_0.5-2_all.deb ...
# Unpacking python3-webencodings (0.5-2) ...
# Selecting previously unselected package python3-html5lib.
# Preparing to unpack .../116-python3-html5lib_0.999999999-1_all.deb ...
# 7Progress: [ 57%] [#################################.........................] 8Unpacking python3-html5lib (0.999999999-1) ...
# Selecting previously unselected package python3-lxml.
# Preparing to unpack .../117-python3-lxml_4.0.0-1_amd64.deb ...
# Unpacking python3-lxml (4.0.0-1) ...
# Selecting previously unselected package python3-numexpr.
# Preparing to unpack .../118-python3-numexpr_2.6.2-2_amd64.deb ...
# 7Progress: [ 58%] [#################################.........................] 8Unpacking python3-numexpr (2.6.2-2) ...
# Selecting previously unselected package python3-tables-lib.
# Preparing to unpack .../119-python3-tables-lib_3.3.0-5build4_amd64.deb ...
# Unpacking python3-tables-lib (3.3.0-5build4) ...
# Selecting previously unselected package python3-tables.
# Preparing to unpack .../120-python3-tables_3.3.0-5build4_all.deb ...
# 7Progress: [ 59%] [##################################........................] 8Unpacking python3-tables (3.3.0-5build4) ...
# Selecting previously unselected package proj-bin.
# Preparing to unpack .../121-proj-bin_4.9.3-2_amd64.deb ...
# Unpacking proj-bin (4.9.3-2) ...
# Setting up libminizip1:amd64 (1.1-8) ...
# 7Progress: [ 60%] [##################################........................] 8Setting up libjs-jquery (3.1.1-2) ...
# Setting up libxerces-c3.1:amd64 (3.1.4+debian-2) ...
# Setting up python3-pickleshare (0.7.4-2) ...
# 7Progress: [ 61%] [###################################.......................] 8Setting up libdap25:amd64 (3.19.0-1) ...
# Setting up libgflags2.2 (2.2.1-1) ...
# Setting up python3-simplegeneric (0.8.1-1) ...
# 7Progress: [ 62%] [###################################.......................] 8Setting up libnetcdf11 (1:4.4.1.1-2ubuntu1) ...
# Setting up python3-webencodings (0.5-2) ...
# Setting up libopenjp2-7:amd64 (2.2.0-1) ...
# 7Progress: [ 63%] [####################################......................] 8Setting up libqhull7:amd64 (2015.2-2) ...
# Setting up liblmdb0:amd64 (0.9.21-1) ...
# Setting up python3-olefile (0.44-1) ...
# 7Progress: [ 64%] [#####################################.....................] 8Setting up liblcms2-2:amd64 (2.7-1ubuntu1) ...
# Setting up libjbig0:amd64 (2.1-3.1) ...
# Setting up poppler-data (0.4.8-1) ...
# 7Progress: [ 65%] [#####################################.....................] 8Setting up libjson-c3:amd64 (0.12.1-1.2) ...
# Setting up python3-numpy (1:1.12.1-3.1ubuntu4) ...
# Setting up libtbb2:amd64 (2017~U7-6) ...
# 7Progress: [ 66%] [######################################....................] 8Setting up mysql-common (5.8+1.0.2ubuntu1) ...
# update-alternatives: using /etc/mysql/my.cnf.fallback to provide /etc/mysql/my.cnf (my.cnf) in auto mode
# Setting up python3-six (1.10.0-4) ...
# Setting up libzstd1 (1.3.1+dfsg-1ubuntu0.1) ...
# 7Progress: [ 67%] [######################################....................] 8Setting up python3-pyparsing (2.1.10+dfsg1-1) ...
# Setting up python3-cycler (0.10.0-1) ...
# Setting up python-tables-data (3.3.0-5build4) ...
# 7Progress: [ 68%] [#######################################...................] 8Setting up libtiff5:amd64 (4.0.8-5ubuntu0.1) ...
# Setting up libgif7:amd64 (5.1.4-1) ...
# Setting up libepsilon1:amd64 (0.9.2+dfsg-2) ...
# 7Progress: [ 69%] [########################################..................] 8Setting up python3-pkg-resources (36.2.7-2) ...
# Setting up python3-bs4 (4.6.0-1) ...
# Setting up libsuperlu5:amd64 (5.2.1+dfsg1-2) ...
# 7Progress: [ 70%] [########################################..................] 8Setting up libnspr4:amd64 (2:4.16-1ubuntu2) ...
# Setting up python3-gflags (1.5.1-3) ...
# update-alternatives: using /usr/bin/python3-gflags2man to provide /usr/bin/gflags2man (gflags2man) in auto mode
# Setting up python3-skimage-lib:amd64 (0.13.0-0ubuntu4) ...
# 7Progress: [ 71%] [#########################################.................] 8Setting up libfreexl1:amd64 (1.0.3-1) ...
# Setting up python3-pandas-lib (0.19.2-5.1ubuntu4) ...
# Setting up libfyba0:amd64 (4.1.1-3) ...
# 7Progress: [ 72%] [#########################################.................] 8Setting up python3-wcwidth (0.1.7+dfsg1-1) ...
# Setting up libxslt1.1:amd64 (1.1.29-2.1ubuntu1) ...
# Setting up libprotobuf10:amd64 (3.0.0-9ubuntu5) ...
# Setting up libdapclient6v5:amd64 (3.19.0-1) ...
# 7Progress: [ 73%] [##########################################................] 8Setting up gdal-data (2.2.1+dfsg-2build3) ...
# Setting up libilmbase12:amd64 (2.2.0-11ubuntu2) ...
# Setting up libyaml-0-2:amd64 (0.1.7-2ubuntu3) ...
# 7Progress: [ 74%] [###########################################...............] 8Setting up python3-protobuf (3.0.0-9ubuntu5) ...
# Setting up libpq5:amd64 (9.6.9-0ubuntu0.17.10) ...
# Setting up python-ptyprocess (0.5.2-1) ...
# 7Progress: [ 75%] [###########################################...............] 8Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
# Setting up python3-ipython-genutils (0.2.0-1) ...
# Setting up python3-nose (1.3.7-2) ...
# Setting up libgoogle-glog0v5 (0.3.5-1) ...
# 7Progress: [ 76%] [############################################..............] 8Setting up python3-chardet (3.0.4-1) ...
# Setting up libsnappy1v5:amd64 (1.1.6-4) ...
# Setting up python3-html5lib (0.999999999-1) ...
# 7Progress: [ 77%] [############################################..............] 8Setting up libjs-jquery-ui (1.12.1+dfsg-5) ...
# Setting up libltdl7:amd64 (2.4.6-2) ...
# Setting up ttf-bitstream-vera (1.10-8) ...
# 7Progress: [ 78%] [#############################################.............] 8Setting up libarpack2:amd64 (3.5.0+real-1) ...
# Setting up cython3 (0.25.2-2build3) ...
# Setting up libboost-python1.62.0 (1.62.0+dfsg-4build3) ...
# 7Progress: [ 79%] [#############################################.............] 8Setting up libmysqlclient20:amd64 (5.7.22-0ubuntu0.17.10.1) ...
# Setting up python3-pywt (0.5.1-1.1ubuntu4) ...
# Setting up javascript-common (11) ...
# 7Progress: [ 80%] [##############################################............] 8Setting up libhdf4-0-alt (4.2.13-1) ...
# Setting up python3-decorator (4.1.1-1) ...
# Setting up python3-traitlets (4.3.2-1) ...
# 7Progress: [ 81%] [##############################################............] 8Setting up python3-ptyprocess (0.5.2-1) ...
# Setting up python3-tz (2017.2-2) ...
# Setting up libboost-system1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# 7Progress: [ 82%] [###############################################...........] 8Setting up libgeos-3.5.1 (3.5.1-3) ...
# Setting up liblzo2-2:amd64 (2.08-1.2) ...
# Setting up liburiparser1:amd64 (0.8.4-1) ...
# 7Progress: [ 83%] [################################################..........] 8Setting up python3-dateutil (2.6.0-1) ...
# Setting up python3-h5py (2.7.1-2) ...
# Setting up fonts-lyx (2.2.3-1) ...
# 7Progress: [ 84%] [################################################..........] 8Setting up proj-data (4.9.3-2) ...
# Setting up libwebp6:amd64 (0.6.0-3) ...
# Setting up python3-pygments (2.2.0+dfsg-1) ...
# 7Progress: [ 85%] [#################################################.........] 8Setting up python3-yaml (3.12-1build2) ...
# Setting up libblosc1 (1.11.1+ds2-2) ...
# Setting up libproj12:amd64 (4.9.3-2) ...
# 7Progress: [ 86%] [#################################################.........] 8Setting up python3-scipy (0.18.1-2ubuntu5) ...
# Setting up python3-prompt-toolkit (1.0.14-1) ...
# Setting up libodbc1:amd64 (2.3.4-1) ...
# 7Progress: [ 87%] [##################################################........] 8Setting up python3-tables-lib (3.3.0-5build4) ...
# Setting up python-matplotlib-data (2.0.0+dfsg1-2ubuntu3) ...
# Setting up python3-lxml (4.0.0-1) ...
# 7Progress: [ 88%] [###################################################.......] 8Setting up libopencv-core3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Setting up python3-numexpr (2.6.2-2) ...
# Setting up libboost-thread1.62.0:amd64 (1.62.0+dfsg-4build3) ...
# 7Progress: [ 89%] [###################################################.......] 8Setting up libnss3:amd64 (2:3.32-1ubuntu3) ...
# Setting up python3-tables (3.3.0-5build4) ...
# Setting up python-pexpect (4.2.1-1) ...
# 7Progress: [ 90%] [####################################################......] 8Setting up libarmadillo7 (1:7.960.1+dfsg-1) ...
# Setting up libopenexr22:amd64 (2.2.0-11ubuntu1) ...
# Setting up libkmlbase1:amd64 (1.3.0-4) ...
# Setting up libleveldb1v5:amd64 (1.20-1) ...
# 7Progress: [ 91%] [####################################################......] 8Setting up libogdi3.2 (3.2.0+ds-2) ...
# Setting up libgeos-c1v5 (3.5.1-3) ...
# Setting up proj-bin (4.9.3-2) ...
# 7Progress: [ 92%] [#####################################################.....] 8Setting up python3-pexpect (4.2.1-1) ...
# Setting up python3-networkx (1.11-1ubuntu1) ...
# Setting up libwebpmux3:amd64 (0.6.0-3) ...
# 7Progress: [ 93%] [######################################################....] 8Setting up libopencv-imgproc3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Setting up libgeotiff2:amd64 (1.4.2-2build1) ...
# Setting up libspatialite7:amd64 (4.3.0a-5build1) ...
# 7Progress: [ 94%] [######################################################....] 8Setting up libkmldom1:amd64 (1.3.0-4) ...
# Setting up python3-pandas (0.19.2-5.1ubuntu4) ...
# Setting up python3-matplotlib (2.0.0+dfsg1-2ubuntu3) ...
# 7Progress: [ 95%] [#######################################################...] 8Setting up libpoppler68:amd64 (0.57.0-2ubuntu4.3) ...
# Setting up python3-leveldb (0~svn68-3build3) ...
# Setting up python3-pil:amd64 (4.1.1-3build2) ...
# 7Progress: [ 96%] [#######################################################...] 8Setting up python3-ipython (5.1.0-3) ...
# Setting up libkmlengine1:amd64 (1.3.0-4) ...
# Setting up python3-skimage (0.13.0-0ubuntu4) ...
# 7Progress: [ 97%] [########################################################..] 8Setting up odbcinst1debian2:amd64 (2.3.4-1) ...
# Setting up odbcinst (2.3.4-1) ...
# Setting up libgdal20 (2.2.1+dfsg-2build3) ...
# 7Progress: [ 98%] [########################################################..] 8Setting up libopencv-imgcodecs3.1:amd64 (3.1.0+dfsg1-1~exp1ubuntu3) ...
# Setting up libcaffe-cuda1:amd64 (1.0.0-3build1) ...
# Setting up python3-caffe-cuda (1.0.0-3build1) ...
# 7Progress: [ 99%] [#########################################################.] 8Setting up caffe-tools-cuda (1.0.0-3build1) ...
# Setting up caffe-cuda (1.0.0-3build1) ...
# Processing triggers for libc-bin (2.26-0ubuntu2.1) ...
#
# 78

# %%
# !git clone https://github.com/bryanyzhu/Hidden-Two-Stream.git
# Out:
# Cloning into 'Hidden-Two-Stream'...
# remote: Counting objects: 707, done.
# remote: Total 707 (delta 0), reused 0 (delta 0), pack-reused 707
# Receiving objects: 100% (707/707), 10.66 MiB | 47.89 MiB/s, done.
# Resolving deltas: 100% (196/196), done.

# %%
# !ls Hidden-Two-Stream/models/multiframe_MotionNet
# Out:
# deploy.prototxt       scripts	       train.prototxt	     val_rgb_split1.txt
# FlowDeltaWeights.txt  solver.prototxt  train_rgb_split1.txt

# %%
# this code only runs on colab <<< 
# step 1 get some token (do this on drive)
#----------------------------------------------------------------------------------------

# Install the PyDrive wrapper & import libraries.
# This only needs to be done once per notebook.
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials
from google.colab import files

# Authenticate and create the PyDrive client.
# This only needs to be done once per notebook.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
# Download a file based on its file ID.
# A file ID looks like: laggVyWshwcyP6kEI-y_W3P8D26sz
file_id = '0B-bJpXHBmFWDVU5DRTY4Ym02TFE'
downloaded = drive.CreateFile({'id': file_id})
downloaded.GetContentFile('MotionNet.caffemodel') # Download file as 'catlove.png' and save it locally

# %%
# !git clone https://github.com/ethereon/caffe-tensorflow.git
# Out:
# Cloning into 'caffe-tensorflow'...
# remote: Counting objects: 479, done.
# remote: Total 479 (delta 0), reused 0 (delta 0), pack-reused 479
# Receiving objects: 100% (479/479), 1.71 MiB | 4.77 MiB/s, done.
# Resolving deltas: 100% (275/275), done.

# %%
# !ls Hidden-Two-Stream/models/multiframe_MotionNet/
# Out:
# deploy.prototxt       scripts	       train.prototxt	     val_rgb_split1.txt
# FlowDeltaWeights.txt  solver.prototxt  train_rgb_split1.txt

# %%
# !./caffe-tensorflow/convert.py Hidden-Two-Stream/models/multiframe_MotionNet/deploy.prototxt --code-output-path=deploy.py
# Out:
# Error encountered: Output shape computation not implemented for type: Deconvolution

# %%
# !./caffe-tensorflow/convert.py Hidden-Two-Stream/models/multiframe_MotionNet/train.prototxt --code-output-path=train.py
# Out:
# Traceback (most recent call last):
#   File "./caffe-tensorflow/convert.py", line 60, in <module>
#     main()
#   File "./caffe-tensorflow/convert.py", line 56, in main
#     args.phase)
#   File "./caffe-tensorflow/convert.py", line 27, in convert
#     transformer = TensorFlowTransformer(def_path, caffemodel_path, phase=phase)
#   File "/content/caffe-tensorflow/kaffe/tensorflow/transformer.py", line 221, in __init__
#     self.load(def_path, data_path, phase)
#   File "/content/caffe-tensorflow/kaffe/tensorflow/transformer.py", line 227, in load
#     graph = GraphBuilder(def_path, phase).build()
#   File "/content/caffe-tensorflow/kaffe/graph.py", line 140, in __init__
#     self.load()
#   File "/content/caffe-tensorflow/kaffe/graph.py", line 146, in load
#     text_format.Merge(def_file.read(), self.params)
#   File "/usr/local/lib/python3.6/dist-packages/google/protobuf/text_format.py", line 536, in Merge
#     descriptor_pool=descriptor_pool)
#   File "/usr/local/lib/python3.6/dist-packages/google/protobuf/text_format.py", line 590, in MergeLines
#     return parser.MergeLines(lines, message)
#   File "/usr/local/lib/python3.6/dist-packages/google/protobuf/text_format.py", line 623, in MergeLines
#     self._ParseOrMerge(lines, message)
#   File "/usr/local/lib/python3.6/dist-packages/google/protobuf/text_format.py", line 638, in _ParseOrMerge
#     self._MergeField(tokenizer, message)
#   File "/usr/local/lib/python3.6/dist-packages/google/protobuf/text_format.py", line 763, in _MergeField
#     merger(tokenizer, message, field)
#   File "/usr/local/lib/python3.6/dist-packages/google/protobuf/text_format.py", line 837, in _MergeMessageField
#     self._MergeField(tokenizer, sub_message)
#   File "/usr/local/lib/python3.6/dist-packages/google/protobuf/text_format.py", line 730, in _MergeField
#     (message_descriptor.full_name, name))
# google.protobuf.text_format.ParseError: 7:3 : Message type "caffe.LayerParameter" has no field named "multi_frame_data_param".

# %%
# !cat Hidden-Two-Stream/models/multiframe_MotionNet/deploy.prototxt
# Out:
# name: "flownet_sd_unsup"
# input: "data"
# input_dim: 1
# input_dim: 33
# input_dim: 256
# input_dim: 320
#
# layer {
#   name: "conv1"
#   type: "Convolution"
#   bottom: "data"
#   top: "conv1"
#   convolution_param {
#     num_output: 64
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "ReLU1"
#   type: "ReLU"
#   bottom: "conv1"
#   top: "conv1"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
#
#
# layer {
#   name: "conv1_1"
#   type: "Convolution"
#   bottom: "conv1"
#   top: "conv1_1"
#   convolution_param {
#     num_output: 64
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "ReLU1_1"
#   type: "ReLU"
#   bottom: "conv1_1"
#   top: "conv1_1"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
#
# layer {
#   name: "conv2"
#   type: "Convolution"
#   bottom: "conv1_1"
#   top: "conv2"
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU2"
#   type: "ReLU"
#   bottom: "conv2"
#   top: "conv2"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "conv2_1"
#   type: "Convolution"
#   bottom: "conv2"
#   top: "conv2_1"
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "ReLU2_1"
#   type: "ReLU"
#   bottom: "conv2_1"
#   top: "conv2_1"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
#
# layer {
#   name: "conv3"
#   type: "Convolution"
#   bottom: "conv2_1"
#   top: "conv3"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU3"
#   type: "ReLU"
#   bottom: "conv3"
#   top: "conv3"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "conv3_1"
#   type: "Convolution"
#   bottom: "conv3"
#   top: "conv3_1"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "ReLU3_1"
#   type: "ReLU"
#   bottom: "conv3_1"
#   top: "conv3_1"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
#
# layer {
#   name: "conv4"
#   type: "Convolution"
#   bottom: "conv3_1"
#   top: "conv4"
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU4"
#   type: "ReLU"
#   bottom: "conv4"
#   top: "conv4"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "conv4_1"
#   type: "Convolution"
#   bottom: "conv4"
#   top: "conv4_1"
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "ReLU4_1"
#   type: "ReLU"
#   bottom: "conv4_1"
#   top: "conv4_1"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
#
# layer {
#   name: "conv5"
#   type: "Convolution"
#   bottom: "conv4_1"
#   top: "conv5"
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU5"
#   type: "ReLU"
#   bottom: "conv5"
#   top: "conv5"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "conv5_1"
#   type: "Convolution"
#   bottom: "conv5"
#   top: "conv5_1"
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "ReLU5_1"
#   type: "ReLU"
#   bottom: "conv5_1"
#   top: "conv5_1"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# #----------------bottlenect layer, conv6 and conv6_1
# layer {
#   name: "conv6"
#   type: "Convolution"
#   bottom: "conv5_1"
#   top: "conv6"
#   convolution_param {
#     num_output: 1024
#     pad: 1
#     kernel_size: 3
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU6"
#   type: "ReLU"
#   bottom: "conv6"
#   top: "conv6"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "conv6_1"
#   type: "Convolution"
#   bottom: "conv6"
#   top: "conv6_1"
#   convolution_param {
#     num_output: 1024
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "ReLU6_1"
#   type: "ReLU"
#   bottom: "conv6_1"
#   top: "conv6_1"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
#
# layer {
#   name: "conv_pr6"
#   type: "Convolution"
#   bottom: "conv6_1"
#   top: "predict_flow6"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
#
# layer {
#   name: "deconv5"
#   type: "Deconvolution"
#   bottom: "conv6_1"
#   top: "deconv5"
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU_up5"
#   type: "ReLU"
#   bottom: "deconv5"
#   top: "deconv5"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "upsample_flow6to5"
#   type: "Deconvolution"
#   bottom: "predict_flow6"
#   top: "upsampled_flow6_to_5"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "concat_5"
#   type: "Concat"
#   bottom: "conv5_1"
#   bottom: "deconv5"
#   bottom: "upsampled_flow6_to_5"
#   top: "concat5"
# }
# layer {
#   name: "smooth_conv5"
#   type: "Convolution"
#   bottom: "concat5"
#   top: "smooth_conv5"
#   convolution_param {
#     num_output: 512
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "conv_pr5"
#   type: "Convolution"
#   bottom: "smooth_conv5"
#   top: "predict_flow5"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
#
# layer {
#   name: "deconv4"
#   type: "Deconvolution"
#   bottom: "smooth_conv5"
#   top: "deconv4"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU_up4"
#   type: "ReLU"
#   bottom: "deconv4"
#   top: "deconv4"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "upsample_flow5to4"
#   type: "Deconvolution"
#   bottom: "predict_flow5"
#   top: "upsampled_flow5_to_4"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "concat_4"
#   type: "Concat"
#   bottom: "conv4_1"
#   bottom: "deconv4"
#   bottom: "upsampled_flow5_to_4"
#   top: "concat4"
# }
# layer {
#   name: "smooth_conv4"
#   type: "Convolution"
#   bottom: "concat4"
#   top: "smooth_conv4"
#   convolution_param {
#     num_output: 256
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "conv_pr4"
#   type: "Convolution"
#   bottom: "smooth_conv4"
#   top: "predict_flow4"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
#
# layer {
#   name: "deconv3"
#   type: "Deconvolution"
#   bottom: "smooth_conv4"
#   top: "deconv3"
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU_up3"
#   type: "ReLU"
#   bottom: "deconv3"
#   top: "deconv3"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "upsample_flow4to3"
#   type: "Deconvolution"
#   bottom: "predict_flow4"
#   top: "upsampled_flow4_to_3"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "concat_3"
#   type: "Concat"
#   bottom: "conv3_1"
#   bottom: "deconv3"
#   bottom: "upsampled_flow4_to_3"
#   top: "concat3"
# }
# layer {
#   name: "smooth_conv3"
#   type: "Convolution"
#   bottom: "concat3"
#   top: "smooth_conv3"
#   convolution_param {
#     num_output: 128
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "conv_pr3"
#   type: "Convolution"
#   bottom: "smooth_conv3"
#   top: "predict_flow3"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
#
# layer {
#   name: "deconv2"
#   type: "Deconvolution"
#   bottom: "smooth_conv3"
#   top: "deconv2"
#   convolution_param {
#     num_output: 64
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "ReLU_up2"
#   type: "ReLU"
#   bottom: "deconv2"
#   top: "deconv2"
#   relu_param {
#     negative_slope: 0.1
#   }
# }
# layer {
#   name: "upsample_flow3to2"
#   type: "Deconvolution"
#   bottom: "predict_flow3"
#   top: "upsampled_flow3_to_2"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 4
#     stride: 2
#   }
# }
# layer {
#   name: "concat_2"
#   type: "Concat"
#   bottom: "conv2_1"
#   bottom: "deconv2"
#   bottom: "upsampled_flow3_to_2"
#   top: "concat2"
# }
# layer {
#   name: "smooth_conv2"
#   type: "Convolution"
#   bottom: "concat2"
#   top: "smooth_conv2"
#   convolution_param {
#     num_output: 64
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
# layer {
#   name: "conv_pr2"
#   type: "Convolution"
#   bottom: "smooth_conv2"
#   top: "predict_flow2"
#   convolution_param {
#     num_output: 20
#     pad: 1
#     kernel_size: 3
#     stride: 1
#   }
# }
